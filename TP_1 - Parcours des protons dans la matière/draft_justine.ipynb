# %% [markdown]
# <a href="https://colab.research.google.com/github/PhD-Brown/PHY-3500/blob/main/TP_1%20-%20Parcours%20des%20protons%20dans%20la%20mati%C3%A8re/draft_justine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Draft - Justine J.
#
# **Instructions:**
# - Utilisez ce notebook pour vos essais et brouillons
# - Ce fichier ne sera pas évalué
# - N'oubliez pas de synchroniser votre travail avec l'équipe

# %%
En r\'esum\'e, une m\'ethode num\'erique est n\'ecessaire pour calculer la port\'ee $R_{\text{CSDA}}$ parce que l'int\'egrande $\rho/S_{\text{col}}(T)$ est une fonction fortement non lin\'eaire de l'\'energie : $S_{\text{col}}(T)$ d\'epend de $\beta(T)$, $\gamma(T)$, de $T_e^{\max}(T)$ et d'un terme logarithmique, ce qui rend l'obtention d'une primitive analytique exploitable irr\'ealiste en pratique. De plus, pr\`es des faibles \'energies, le pouvoir d'arr\^et varie tr\`es rapidement (et tend \`a diverger quand $T \to 0$), ce qui exige un contr\^ole fin du pas d'int\'egration (et justifie l'usage d'une borne $T_{\min}$). Finalement, d\`es qu'on veut utiliser des donn\'ees/tabulations (ex.\ bases NIST) ou ajouter des corrections, la quadrature num\'erique devient la seule approche robuste. C'est pourquoi on passe ensuite aux m\'ethodes des trap\`ezes et de Simpson pour estimer $R_{\text{CSDA}}$ avec une erreur contr\^ol\'ee.

# %%
# Importations
import numpy as np
import matplotlib.pyplot as plt

# Configuration pour les graphiques
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Vos notes et essais ici

# %%
test
