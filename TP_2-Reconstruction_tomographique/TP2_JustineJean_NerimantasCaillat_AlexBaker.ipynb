# %% [markdown]
# <div style="width: 98%; max-width: 1200px; margin: 0 auto; font-family: Helvetica, Arial, sans-serif;">
#
# <div style="
#         background-color: #141E30;
#         background-image: linear-gradient(to right, #141E30, #243B55);
#         border-radius: 10px;
#         padding: 25px;
#         text-align: center;
#         margin-bottom: 20px;
#         border: 1px solid #2c3e50;
#         box-shadow: 0 4px 8px rgba(0,0,0,0.3);
#     ">
#         <h1 style="color: white; margin: 0; text-transform: uppercase; font-size: 24px; font-weight: normal; letter-spacing: 2px;">
#             TP 2 :  Reconstruction tomographique
#         </h1>
#         <h3 style="color: #a8d0e6; margin-top: 10px; margin-bottom: 0; font-weight: normal; font-style: italic; font-size: 16px;">
#             Se familiariser avec diverses approches classiques de
# reconstruction tomographique.
#         </h3>
#     </div>
#
#
# <div style="background-color: #141E30; border: 2px solid #a8d0e6; border-radius: 10px; padding: 20px; color: white;">
#
# ### Équipe de recherche
# **Alex Baker** - 537 050 929
# **Justine Jean** - 537 287 332
# **Nerimantas Caillat** - 537 396 153
#
# ### Informations académiques
# **Cours :** PHY-3500 – Physique numérique (H26)
# **Remise :** 23 février 2026
# **Encadrement :** Pr. Antoine Allard, Thomas Labbé, Philippe Després
#
# </div>
#
# </div>
# ---

# %% [markdown]
# ## Instructions
#
# 1. Remplissez les informations de l'équipe ci-dessus
# 2. Complétez chaque section du TP
# 3. Assurez-vous que toutes les cellules s'exécutent sans erreur
# 4. Sauvegardez vos figures dans le dossier `figs/`
# 5. Sauvegardez vos résultats dans le dossier `results/`
# 6. Renommez ce fichier: `TP2_nom1_nom2_nom3.ipynb`
#
# ### ⚠️ Instructions pour la remise
#
# **IMPORTANT:** Le travail doit être soumis sous la forme d'un **seul** cahier Jupyter (`.ipynb`) contenant **toutes les informations pertinentes**, incluant **tout le code Python utilisé**.
#
# - **Tout le code Python doit apparaître directement dans le notebook remis**
# - Le code ne doit **PAS** être uniquement présent dans des modules `.py` externes appelés depuis le notebook
# - Le cahier remis doit être **autoportant** avec l'ensemble du code Python visible à l'intérieur du notebook lui-même
# - Un seul fichier `.ipynb` doit être transmis (nommé `TP2_nom1_nom2_nom3.ipynb`)
#
# **Note:** Vous pouvez utiliser les modules dans `src/` pendant votre développement, mais lors de la remise finale, copiez toutes les fonctions nécessaires directement dans le notebook.

# %%
# Importations
import numpy as np
import matplotlib.pyplot as plt

# Configuration
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ### Objectifs et Contexte
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #9C27B0; padding: 15px; border-radius: 5px; margin-top: 20px;">
#
# <strong style="color: #E1BEE7; font-size: 1.1em;">Contexte clinique :</strong>
# <br><br>
# La tomodensitométrie permet d’imager l’intérieur d’un objet de façon non invasive en mesurant l’atténuation des rayons X. En clinique (≈ 30–140 keV), on acquiert de nombreuses projections en faisant tourner une source et un détecteur autour de l’objet, puis on reconstruit une carte d’atténuation (liée à la densité).
#
# <strong style="color: #E1BEE7; font-size: 1.1em;">But du TP :</strong>
# <br>
# 1. **Atténuation / Beer–Lambert** : estimer µ (eau, 60 keV) à partir de XCOM et prédire la fraction transmise après différentes épaisseurs.
#
# 2. **Reconstruction par rétroprojection** : partir du sinogramme, reconstruire (laminogramme), puis rétroprojection filtrée (FBP) et comparer au fantôme (erreurs/artéfacts).
#
# 3. **Reconstruction Fourier** : implémenter la méthode Fourier Slice (TF2D), tester interpolation/sur-échantillonnage (Nyquist) et comparer la qualité et le temps de calcul.
# </div>

# %% [markdown]
# <div style="height: 50px;"></div> <hr style="border: 0; height: 3px; background-color: #2196F3; border-radius: 2px; opacity: 0.7;">
# <br />
#
# # Question 1 : Estimation de µ (eau, 60 keV) via XCOM et impact sur l’intensité détectée
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #2196F3; padding: 15px; border-radius: 5px;">
#
# **Énoncé :** *Supposons, pour simplifier, que le corps humain est fait d’eau pure. Grâce à la base de données XCOM du NIST, trouvez le µ de l’eau pour des photons de 60 keV, à une masse volumique de 1.0 $g/cm^3$. Quelle fraction du signal subsiste après avoir traversé 5 cm d’eau ; 20 cm d’eau* ?
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div> <hr style="border: 0; height: 3px; background-color: #2196F3; border-radius: 2px; opacity: 0.7;">
# <br />
#
# # Question 2 : Reconstruction par rétroprojection
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #2196F3; padding: 15px; border-radius: 5px;">
#
# **Énoncé :** *En utilisant le code fourni (ou pas), créer une rétroprojection simple, aussi appelée laminogramme, des données de projection fournies. Notez qu’une approche par slicing pourrait accélérer votre algorithme. Votre code utilisera la méthode du plus proche voisin pour déterminer la valeur de projection à utiliser (le rayon passant par la source et le voxel d’intérêt n’aboutit pas nécessairement au centre des pixels du détecteur).
# Une fois que vous aurez accès au fantôme numérique, comparez-le à la reconstruction. Qualitativement, quelles différences observez-vous entre l’image reconstruite et l’image de référence (fantôme)*?
#
#
# </div>
#
# <br />

# %% [markdown]
# <div style="height: 50px;"></div> <hr style="border: 0; height: 3px; background-color: #2196F3; border-radius: 2px; opacity: 0.7;">
# <br />
#
# # Question 3 : Différences entre le sinogramme fourni et filtré
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #2196F3; padding: 15px; border-radius: 5px;">
#
# **Énoncé :** *En utilisant la librairie numpy.fft, implémentez le filtre passe-haut proposé pour filtrer le sinogramme une projection à la fois. Affichez et sauvegardez l’image du sinogramme filtré. Qualitativement, quelles sont les principales différences entre le sinogramme fourni et filtré?*
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div> <hr style="border: 0; height: 3px; background-color: #2196F3; border-radius: 2px; opacity: 0.7;">
# <br />
#
# # Question 4 : Rétroprojection filtrée : comparaison au fantôme et analyse des artéfacts
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #2196F3; padding: 15px; border-radius: 5px;">
#
# **Énoncé :** *Ayant en main le sinogramme filtré, effectuez une rétroprojection filtrée, en récupérant idéalement le code précédent du laminogramme. Comparez l’image obtenue avec le fantôme. Quelles différences observez-vous *?* Où sont situées les erreurs et que diriez-vous de la fréquence spatiale des erreurs*?
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div> <hr style="border: 0; height: 3px; background-color: #2196F3; border-radius: 2px; opacity: 0.7;">
# <br />
#
# # Question 5 : Raffinement de la rétroprojection : estimation plus précise de l’atténuation par voxel
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #2196F3; padding: 15px; border-radius: 5px;">
#
# **Énoncé :** *Tentons d’améliorer la qualité d’image davantage. Ecrivez une nouvelle fonction dans geometry.py qui permet d’ajouter une valeur d’atténuation plus précise à chaque voxel lors de la rétroprojection. Au lieu d’identifier le pixel plus proche voisin sur le détecteur de radiation, utilisez l’interpolation linéaire entre deux pixels adjacents sur le détecteur.
# Comment l’image s’est-elle améliorée ? Pour référence future, enregistrez le temps de reconstruction total.*
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div> <hr style="border: 0; height: 3px; background-color: #2196F3; border-radius: 2px; opacity: 0.7;">
# <br />
#
# # Question 6 : Reconstruction par le théorème de la tranche de Fourier (TF2D) : du sinogramme à l’image
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #2196F3; padding: 15px; border-radius: 5px;">
#
# **Énoncé :** *Écrivez une nouvelle fonction de reconstruction reconFourierSlice() qui effectue la reconstruction via le théorème de la tranche de Fourier. Il faut effecteur la TF 1D de chaque projection du sinogramme et stocker le nouveau sinogramme transformé. Par échantillonnage du sinogramme, remplissez l’espace de Fourier 2D de l’image à reconstruire. Vous pouvez choisir l’angle approprié par la méthode du plus proche voisin et la position sur le détecteur par interpolation linéaire. Trouvez l’image par $TF^{-1}_{2D}$
# Indice : considérez toutes les données comme des nombres complexes avec l’initialisation suivante mymatrix = numpy.zeros((a,b), ’complex’) afin d’éviter les changements de taille, puis prenez la partie réelle de l’image finale.*
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div>
# <hr style="border: 0; height: 3px; background-color: #2196F3; border-radius: 2px; opacity: 0.7;">
# <br />
#
# # Question 7 : $TF_{2D}$ (Fourier slice) : discussion du rendu et du temps d’exécution
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #2196F3; padding: 15px; border-radius: 5px;">
#
# **Énoncé :** *Incluez dans le rapport et décrivez brièvement le résultat obtenu. Il est fort probable que l’image soit loin de vos attentes, même si le code est correct. Notez également le temps de reconstruction.*
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div> <hr style="border: 0; height: 3px; background-color: #2196F3; border-radius: 2px; opacity: 0.7;">
# <br />
#
# # Question 8 : Reconstruction sur-échantillonnée : résolution, artefacts et limites liées à la TF
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #2196F3; padding: 15px; border-radius: 5px;">
#
# **Énoncé :** *Tentez de reconstruire l’image en soumettant une grille d’image deux fois plus dense dans chaque direction (doubler le nombre de voxels et réduire leur taille deux fois dans le fichier geometry.py). Quelles améliorations observez-vous ? L’image est-elle acceptable pour un diagnostic médical ? Basez votre discussion sur la définition-même de la TF et
# sur le théorème de Nyquist-Shannon.*
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div> <hr style="border: 0; height: 3px; background-color: #2196F3; border-radius: 2px; opacity: 0.7;">
# <br />
#
# # Question 9 : Complexité algorithmique et performance : boucles imbriquées et slicing en reconstruction
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #2196F3; padding: 15px; border-radius: 5px;">
#
# **Énoncé :** *Comparez les temps de reconstruction de la rétroprojection filtrée, la reconstruction ${TF}_{2D}$ et cette dernière avec sur-échantillonnage. Discutez de la taille des boucles for imbriquées dans ces trois cas et/ou de l’utilité du slicing si applicable.*
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div> <hr style="border: 0; height: 3px; background-color: #2196F3; border-radius: 2px; opacity: 0.7;">
# <br />
#
# # Question 10 (bonus) : Amélioration TF2D par interpolation bi-linéaire : observation et temps d’exécution
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #2196F3; padding: 15px; border-radius: 5px;">
#
# **Énoncé :** *Implémentez une fonction d’interpolation bi-linéaire pour la méthode TF2D, qui se fie à quatre voisins du voxel échantillonné. Observez-vous une amélioration ? Qu’en est-il du temps de reconstruction ?*
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div> <hr style="border: 0; height: 3px; background-color: #2196F3; border-radius: 2px; opacity: 0.7;">
# <br />
#
# ## Références

# %% [markdown]
# <div style="height: 50px;"></div> <hr style="border: 0; height: 3px; background-color: #2196F3; border-radius: 2px; opacity: 0.7;">
# <br />
#
# ## Annexes

# %% [markdown]
# <div style="
#     margin-top: 30px;
#     padding: 15px;
#     background: linear-gradient(135deg, rgba(15, 12, 41, 0.5), rgba(48, 43, 99, 0.3));
#     border-radius: 8px;
#     border: 1px solid rgba(168, 208, 230, 0.1);
#     text-align: center;
# ">
#     <p style="color: rgba(168, 208, 230, 0.5); font-size: 12px; margin: 0; letter-spacing: 1px;">
#         PHY-3500 — Physique numérique (H26) — TP 2 : Reconstruction tomographique
#     </p>
#     <p style="color: rgba(168, 208, 230, 0.35); font-size: 11px; margin: 5px 0 0 0;">
#         Alex Baker • Justine Jean • Nerimantas Caillat
#     </p>
# </div>
