# %% [markdown]
# <div style="width: 98%; max-width: 1200px; margin: 0 auto; font-family: Helvetica, Arial, sans-serif;">
#
# <div style="
#         background: linear-gradient(135deg, #0f0c29 0%, #302b63 50%, #24243e 100%);
#         border-radius: 15px;
#         padding: 35px;
#         text-align: center;
#         margin-bottom: 25px;
#         border: 1px solid rgba(168, 208, 230, 0.3);
#         box-shadow: 0 8px 32px rgba(0,0,0,0.4), inset 0 1px 0 rgba(255,255,255,0.1);
#         position: relative;
#         overflow: hidden;
#     ">
#         <div style="position: absolute; top: -50%; left: -50%; width: 200%; height: 200%; background: radial-gradient(circle at 30% 70%, rgba(33, 150, 243, 0.08) 0%, transparent 50%); pointer-events: none;"></div>
#         <p style="color: rgba(168, 208, 230, 0.6); font-size: 12px; letter-spacing: 6px; text-transform: uppercase; margin: 0 0 10px 0; font-weight: 300;">PHY-3500 — Physique numérique</p>
#         <p style="color: rgba(168, 208, 230, 0.4); font-size: 10px; letter-spacing: 2px; margin: 0 0 8px 0;">TP2_AlexBaker_NerimantasCaillat_JustineJean.ipynb</p>
#         <h1 style="color: white; margin: 0; text-transform: uppercase; font-size: 28px; font-weight: 300; letter-spacing: 3px; text-shadow: 0 2px 10px rgba(33, 150, 243, 0.3);">
#             TP 2 : Reconstruction tomographique
#         </h1>
#         <div style="width: 80px; height: 3px; background: linear-gradient(90deg, transparent, #2196F3, transparent); margin: 15px auto;"></div>
#         <h3 style="color: #a8d0e6; margin-top: 10px; margin-bottom: 0; font-weight: 300; font-style: italic; font-size: 15px; letter-spacing: 1px;">
#             Reconstruction d'images à partir de données de projection — Tomodensitométrie
#         </h3>
#     </div>
#
# <div style="
#     background: linear-gradient(135deg, #0f0c29 0%, #1a1a2e 100%);
#     border: 2px solid rgba(168, 208, 230, 0.25);
#     border-radius: 12px;
#     padding: 25px;
#     color: white;
#     box-shadow: 0 4px 20px rgba(0,0,0,0.3);
# ">
#
# <div style="display: flex; align-items: center; margin-bottom: 15px;">
#     <div style="width: 4px; height: 25px; background: #2196F3; border-radius: 2px; margin-right: 12px;"></div>
#     <h3 style="margin: 0; color: #a8d0e6; font-weight: 400; letter-spacing: 1px;">Équipe de recherche</h3>
# </div>
#
# **Alex Baker** — 537 050 929
# **Justine Jean** — 537 287 332
# **Nerimantas Caillat** — 537 396 153
#
# <div style="width: 100%; height: 1px; background: linear-gradient(90deg, transparent, rgba(168, 208, 230, 0.3), transparent); margin: 15px 0;"></div>
#
# <div style="display: flex; align-items: center; margin-bottom: 15px;">
#     <div style="width: 4px; height: 25px; background: #2196F3; border-radius: 2px; margin-right: 12px;"></div>
#     <h3 style="margin: 0; color: #a8d0e6; font-weight: 400; letter-spacing: 1px;">Informations académiques</h3>
# </div>
#
# **Cours :** PHY-3500 – Physique numérique (H26)
# **Remise :** 23 février 2026
# **Encadrement :** Pr. Antoine Allard, Thomas Labbé, Philippe Després
# **Auteurs de l'énoncé :** Dmitri Matenine et Philippe Després
#
# </div>
#
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #302b63 0%, #24243e 50%, #0f0c29 100%);
#     padding: 25px 30px;
#     border-radius: 12px;
#     margin: 30px 0 20px 0;
#     box-shadow: 0 8px 25px rgba(48, 43, 99, 0.4);
#     border: 1px solid rgba(168, 208, 230, 0.15);
# ">
#     <h2 style="color: white; margin: 0; text-align: center; font-size: 22px; font-weight: 300; letter-spacing: 2px; text-shadow: 0 2px 8px rgba(0,0,0,0.3);">📑 TABLE DES MATIÈRES</h2>
# </div>
#
# <div style="display: grid; grid-template-columns: repeat(2, 1fr); gap: 12px; margin: 20px 0;">
#
# <div style="background: linear-gradient(135deg, #0f0c29, #302b63); padding: 18px; border-radius: 10px; box-shadow: 0 4px 15px rgba(15, 12, 41, 0.4); border: 1px solid rgba(168, 208, 230, 0.15);">
#     <a href="#intro" style="color: white; text-decoration: none;">
#         <strong style="font-size: 14px; display: block; margin-bottom: 6px;">Introduction & Configuration</strong>
#         <span style="font-size: 11px; opacity: 0.7;">Contexte, objectifs, imports</span>
#     </a>
# </div>
#
# <div style="background: linear-gradient(135deg, #302b63, #24243e); padding: 18px; border-radius: 10px; box-shadow: 0 4px 15px rgba(48, 43, 99, 0.4); border: 1px solid rgba(168, 208, 230, 0.15);">
#     <a href="#q1" style="color: white; text-decoration: none;">
#         <strong style="font-size: 14px; display: block; margin-bottom: 6px;">Question 1 — Atténuation</strong>
#         <span style="font-size: 11px; opacity: 0.7;">Loi de Beer-Lambert, µ de l'eau</span>
#     </a>
# </div>
#
# <div style="background: linear-gradient(135deg, #24243e, #0f0c29); padding: 18px; border-radius: 10px; box-shadow: 0 4px 15px rgba(36, 36, 62, 0.4); border: 1px solid rgba(168, 208, 230, 0.15);">
#     <a href="#q2" style="color: white; text-decoration: none;">
#         <strong style="font-size: 14px; display: block; margin-bottom: 6px;">Question 2 — Rétroprojection simple</strong>
#         <span style="font-size: 11px; opacity: 0.7;">Laminogramme, plus proche voisin</span>
#     </a>
# </div>
#
# <div style="background: linear-gradient(135deg, #0f0c29, #302b63); padding: 18px; border-radius: 10px; box-shadow: 0 4px 15px rgba(15, 12, 41, 0.4); border: 1px solid rgba(168, 208, 230, 0.15);">
#     <a href="#q3" style="color: white; text-decoration: none;">
#         <strong style="font-size: 14px; display: block; margin-bottom: 6px;">Question 3 — Filtre passe-haut</strong>
#         <span style="font-size: 11px; opacity: 0.7;">Filtre |u|, domaine fréquentiel</span>
#     </a>
# </div>
#
# <div style="background: linear-gradient(135deg, #302b63, #24243e); padding: 18px; border-radius: 10px; box-shadow: 0 4px 15px rgba(48, 43, 99, 0.4); border: 1px solid rgba(168, 208, 230, 0.15);">
#     <a href="#q4" style="color: white; text-decoration: none;">
#         <strong style="font-size: 14px; display: block; margin-bottom: 6px;">Question 4 — Rétroprojection filtrée</strong>
#         <span style="font-size: 11px; opacity: 0.7;">FBP, comparaison au fantôme</span>
#     </a>
# </div>
#
# <div style="background: linear-gradient(135deg, #24243e, #0f0c29); padding: 18px; border-radius: 10px; box-shadow: 0 4px 15px rgba(36, 36, 62, 0.4); border: 1px solid rgba(168, 208, 230, 0.15);">
#     <a href="#q5" style="color: white; text-decoration: none;">
#         <strong style="font-size: 14px; display: block; margin-bottom: 6px;">Question 5 — Interpolation linéaire</strong>
#         <span style="font-size: 11px; opacity: 0.7;">Amélioration de la rétroprojection</span>
#     </a>
# </div>
#
# <div style="background: linear-gradient(135deg, #0f0c29, #302b63); padding: 18px; border-radius: 10px; box-shadow: 0 4px 15px rgba(15, 12, 41, 0.4); border: 1px solid rgba(168, 208, 230, 0.15);">
#     <a href="#q6" style="color: white; text-decoration: none;">
#         <strong style="font-size: 14px; display: block; margin-bottom: 6px;">Question 6 — Tranche de Fourier</strong>
#         <span style="font-size: 11px; opacity: 0.7;">Fourier Slice Theorem, TF 2D</span>
#     </a>
# </div>
#
# <div style="background: linear-gradient(135deg, #302b63, #24243e); padding: 18px; border-radius: 10px; box-shadow: 0 4px 15px rgba(48, 43, 99, 0.4); border: 1px solid rgba(168, 208, 230, 0.15);">
#     <a href="#q7" style="color: white; text-decoration: none;">
#         <strong style="font-size: 14px; display: block; margin-bottom: 6px;">Question 7 — Résultat TF2D</strong>
#         <span style="font-size: 11px; opacity: 0.7;">Analyse de la reconstruction</span>
#     </a>
# </div>
#
# <div style="background: linear-gradient(135deg, #24243e, #0f0c29); padding: 18px; border-radius: 10px; box-shadow: 0 4px 15px rgba(36, 36, 62, 0.4); border: 1px solid rgba(168, 208, 230, 0.15);">
#     <a href="#q8" style="color: white; text-decoration: none;">
#         <strong style="font-size: 14px; display: block; margin-bottom: 6px;">Question 8 — Sur-échantillonnage</strong>
#         <span style="font-size: 11px; opacity: 0.7;">Nyquist-Shannon, grille 2×</span>
#     </a>
# </div>
#
# <div style="background: linear-gradient(135deg, #0f0c29, #302b63); padding: 18px; border-radius: 10px; box-shadow: 0 4px 15px rgba(15, 12, 41, 0.4); border: 1px solid rgba(168, 208, 230, 0.15);">
#     <a href="#q9" style="color: white; text-decoration: none;">
#         <strong style="font-size: 14px; display: block; margin-bottom: 6px;">Question 9 — Comparaison des temps</strong>
#         <span style="font-size: 11px; opacity: 0.7;">FBP vs TF2D, complexité</span>
#     </a>
# </div>
#
# <div style="background: linear-gradient(135deg, #302b63, #24243e); padding: 18px; border-radius: 10px; box-shadow: 0 4px 15px rgba(48, 43, 99, 0.4); border: 1px solid rgba(168, 208, 230, 0.15); grid-column: 1 / -1;">
#     <a href="#q10" style="color: white; text-decoration: none;">
#         <strong style="font-size: 14px; display: block; margin-bottom: 6px;">Question 10 (BONUS) — Interpolation bilinéaire</strong>
#         <span style="font-size: 11px; opacity: 0.7;">Quatre voisins, amélioration TF2D</span>
#     </a>
# </div>
#
# </div>
#
# <div style="text-align: center; margin: 20px 0; padding: 12px; background: linear-gradient(135deg, rgba(48, 43, 99, 0.15), rgba(15, 12, 41, 0.15)); border-radius: 8px; border: 1px solid rgba(168, 208, 230, 0.15);">
#     <p style="margin: 0; color: #a8d0e6; font-size: 12px;"><strong>Navigation rapide :</strong> Cliquez sur une section pour y accéder directement</p>
# </div>

# %% [markdown]
# <div style="margin: 40px 0;">
#     <div style="height: 3px; background: linear-gradient(90deg, transparent, #2196F3, #9C27B0, #2196F3, transparent); border-radius: 3px;"></div>
# </div>
#
# <a id="intro"></a>
#
# <div style="
#     background: linear-gradient(135deg, #0f0c29 0%, #302b63 100%);
#     padding: 22px 30px;
#     border-radius: 12px;
#     margin: 30px 0 20px 0;
#     box-shadow: 0 8px 25px rgba(15, 12, 41, 0.5);
#     border: 1px solid rgba(168, 208, 230, 0.15);
# ">
#     <h2 style="color: white; margin: 0; text-align: center; font-size: 24px; font-weight: 300; letter-spacing: 2px; text-shadow: 0 2px 8px rgba(0,0,0,0.3);">INTRODUCTION & CONFIGURATION</h2>
# </div>
#
# ### Objectif
#
# Effectuer des reconstructions tomographiques à l'aide du langage de programmation Python à partir de données de projection. Se familiariser avec diverses approches classiques de reconstruction tomographique.
#
# ### Contexte
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #9C27B0; padding: 15px; border-radius: 5px; margin-top: 10px;">
#
# <strong style="color: #CE93D8; font-size: 1.05em;">Tomographie :</strong><br><br>
# La tomodensitométrie (TDM / CT scan) est une technique d'imagerie non invasive permettant de reconstruire la distribution de densité d'un objet tranche par tranche. Le principe repose sur la mesure de l'atténuation partielle d'un faisceau de rayons X traversant l'objet sous différents angles.
#
# Les fondements théoriques ont été énoncés par le mathématicien **Johann Radon** en 1917. L'invention du tomodensitomètre médical est attribuée à **Sir Godfrey Hounsfield** et **Allan McLeod Cormack** (prix Nobel de médecine 1979).
#
# **Géométrie :** On utilise ici une géométrie à faisceaux parallèles, où le paramètre $t \in [0, 1]$ désigne la position relative sur le détecteur et $\varphi \in [0, 2\pi[$ l'angle du statif. L'ensemble des mesures forme le sinogramme.
#
# </div>
#
# ### Loi de Beer-Lambert
#
# L'atténuation des rayons X est modélisée par :
#
# $$I = I_0 \exp\left(-\int \mu(x)\,dx\right) \quad \Longrightarrow \quad \ln\frac{I_0}{I} = \sum \mu(x)\,\Delta x$$
#
# où $\mu(x)$ est le **coefficient d'atténuation linéaire** (la quantité à reconstruire).

# %%
# Configuration et importation des modules
"""
Ce notebook implémente différentes méthodes de reconstruction tomographique :
  - Rétroprojection simple (laminogramme)
  - Rétroprojection filtrée (FBP)
  - Reconstruction via le théorème de la tranche de Fourier (FST)
"""

# Calcul scientifique
import numpy as np
from numpy.fft import fft, ifft, ifft2, fftshift, ifftshift, fftfreq

# Visualisation
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.ndimage import zoom

# Mesure de performance
import time
import platform

# Configuration esthétique des graphiques
plt.rcParams.update({
    'figure.figsize': (12, 7),
    'figure.dpi': 100,
    'font.size': 11,
    'font.family': 'serif',
    'axes.labelsize': 12,
    'axes.titlesize': 14,
    'axes.titleweight': 'bold',
    'axes.grid': True,
    'grid.alpha': 0.3,
    'lines.linewidth': 2,
    'legend.fontsize': 11,
    'legend.framealpha': 0.9,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'image.cmap': 'gray',
})

print(f"NumPy version : {np.__version__}")
print(f"Python version : {platform.python_version()}")
print(f"Plateforme : {platform.system()} {platform.release()}")
# Out:
# NumPy version : 2.4.1
# Python version : 3.11.9
# Plateforme : Windows 10

# %% [markdown]
# <div style="background-color: #1a1a2e; color: #a8d0e6; border-left: 5px solid #2196F3; padding: 12px 16px; border-radius: 5px; margin: 10px 0; font-size: 0.9em;">
# <strong>Données d'entrée :</strong> Chargement et visualisation des sinogrammes bruts (<em>password</em> et <em>patient</em>) et des angles d'acquisition.
# </div>

# %%
# Chargement des sinogrammes et angles fournis avec l'énoncé
sinogram_password = np.loadtxt('sinogram-password.txt')
sinogram_patient  = np.loadtxt('sinogram-patient.txt')
angles            = np.deg2rad(np.loadtxt('angles.txt'))

print(f"Sinogramme (password) : {sinogram_password.shape}")
print(f"Sinogramme (patient)  : {sinogram_patient.shape}")
print(f"Angles                : {angles.shape}  (de {np.degrees(angles[0]):.1f}° à {np.degrees(angles[-1]):.1f}°)")

# Visualisation des sinogrammes bruts
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

im0 = axes[0].imshow(sinogram_password, aspect='auto', cmap='inferno')
axes[0].set_title('Sinogramme — Password')
axes[0].set_xlabel('Position du détecteur (pixel)')
axes[0].set_ylabel('Projection (angle)')
plt.colorbar(im0, ax=axes[0], label=r'$\ln(I_0/I)$')

im1 = axes[1].imshow(sinogram_patient, aspect='auto', cmap='inferno')
axes[1].set_title('Sinogramme — Patient')
axes[1].set_xlabel('Position du détecteur (pixel)')
axes[1].set_ylabel('Projection (angle)')
plt.colorbar(im1, ax=axes[1], label=r'$\ln(I_0/I)$')

fig.suptitle('Données brutes : Sinogrammes', fontsize=16, fontweight='bold', y=1.02)
fig.tight_layout()
plt.show()
# Out:
# Sinogramme (password) : (720, 336)
# Sinogramme (patient)  : (720, 336)
# Angles                : (720,)  (de 90.5° à 90.0°)

# %% [markdown]
# <div style="height: 50px;"></div>
# <div style="position: relative; margin: 30px 0;">
#     <div style="height: 3px; background: linear-gradient(90deg, transparent, #2196F3, #E91E63, #2196F3, transparent); border-radius: 3px;"></div>
#     <div style="position: absolute; top: 50%; left: 50%; transform: translate(-50%, -50%); background: #1e1e1e; padding: 0 20px;">
#         <span style="color: #2196F3; font-size: 18px; font-weight: bold; letter-spacing: 3px;">✦ ✦ ✦</span>
#     </div>
# </div>
# <br />
#
# <a id="q1"></a>
#
# <div style="
#     background: linear-gradient(135deg, #0f0c29 0%, #302b63 100%);
#     padding: 22px 30px;
#     border-radius: 12px;
#     margin: 10px 0 20px 0;
#     box-shadow: 0 8px 25px rgba(15, 12, 41, 0.5);
#     border: 1px solid rgba(33, 150, 243, 0.3);
#     border-left: 5px solid #2196F3;
# ">
#     <div style="display: flex; align-items: center; gap: 15px;">
#         <div style="
#             background: linear-gradient(135deg, #2196F3, #1565C0);
#             color: white;
#             width: 45px; height: 45px;
#             border-radius: 50%;
#             display: flex; align-items: center; justify-content: center;
#             font-size: 20px; font-weight: bold;
#             box-shadow: 0 4px 15px rgba(33, 150, 243, 0.4);
#             flex-shrink: 0;
#         ">1</div>
#         <h2 style="color: white; margin: 0; font-size: 22px; font-weight: 300; letter-spacing: 1px;">Atténuation des rayons X — Coefficient µ de l'eau</h2>
#     </div>
# </div>
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #2196F3; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# **Énoncé :** *Supposons, pour simplifier, que le corps humain est fait d'eau pure. Grâce à la base de données XCOM du NIST ([lien](http://physics.nist.gov/PhysRefData/Xcom/html/xcom1.html)), trouvez le µ de l'eau pour des photons de 60 keV, à une masse volumique de 1.0 g/cm³. Quelle fraction du signal subsiste après avoir traversé 5 cm d'eau ; 20 cm d'eau ?*
#
# </div>

# %%
# Données NIST XCOM pour l'eau à 60 keV
# https://physics.nist.gov/PhysRefData/Xcom/html/xcom1.html
# Pour H2O à 60 keV : μ/ρ = 0.2059 cm²/g

mu_sur_rho = 0.2059  # cm²/g (coefficient d'atténuation massique)
rho_eau = 1.0        # g/cm³ (masse volumique de l'eau)

# Coefficient d'atténuation linéaire
mu = mu_sur_rho * rho_eau  # cm⁻¹

# Loi de Beer-Lambert : I = I₀ exp(-μx)
# Cas 1 : 5 cm d'eau
x1 = 5.0  # cm
fraction_5cm = np.exp(-mu * x1)
attenuation_5cm = (1 - fraction_5cm) * 100

# Cas 2 : 20 cm d'eau
x2 = 20.0  # cm
fraction_20cm = np.exp(-mu * x2)
attenuation_20cm = (1 - fraction_20cm) * 100

print(f"μ = {mu:.4f} cm⁻¹")
print(f"Traversée 5 cm  : {fraction_5cm:.4f} ({fraction_5cm*100:.2f}% transmis)")
print(f"Traversée 20 cm : {fraction_20cm:.6f} ({fraction_20cm*100:.4f}% transmis)")
# Out:
# μ = 0.2059 cm⁻¹
# Traversée 5 cm  : 0.3572 (35.72% transmis)
# Traversée 20 cm : 0.016277 (1.6277% transmis)

# %% [markdown]
# <div style="background-color: #252526; color: white; border-left: 5px solid #2196F3; padding: 15px; border-radius: 5px; margin-top: 20px;">
#
# <strong style="color: #90CAF9; font-size: 1.05em;">Interprétation physique :</strong>
# <br><br>
#
# #### Décroissance exponentielle
#
# Les graphiques montrent clairement la nature exponentielle de l'atténuation :
# - **Échelle linéaire** : décroissance rapide dans les premiers centimètres
# - **Échelle logarithmique** : relation linéaire → confirme $\ln(I/I_0) = -\mu x$
#
# #### Implications pour la tomographie
#
# En tomodensitométrie (TDM), on mesure l'intensité transmise $I$ pour retrouver le coefficient d'atténuation :
#
# $$-\ln\left(\frac{I}{I_0}\right) = \mu \cdot x$$
#
# Chaque projection du sinogramme correspond à l'intégrale des coefficients d'atténuation le long d'un rayon. La reconstruction consiste à inverser cette transformation de Radon pour retrouver la distribution spatiale de $\mu(x, y)$.
#
# **Points clés :**
# - L'atténuation augmente exponentiellement avec l'épaisseur
# - Le logarithme transforme la relation en somme linéaire
# - Cette propriété est fondamentale pour la reconstruction tomographique
#
# </div>

# %%
# Visualisation : Courbe d'atténuation en fonction de l'épaisseur
x_range = np.linspace(0, 30, 500)
I_sur_I0 = np.exp(-mu * x_range)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))

# Graphique 1 : Échelle linéaire
ax1.plot(x_range, I_sur_I0, 'b-', linewidth=2.5, label=r'$I/I_0 = e^{-\mu x}$')
ax1.axvline(5, color='red', linestyle='--', alpha=0.7, linewidth=2, label=f'x = 5 cm → {fraction_5cm:.1%}')
ax1.axvline(20, color='orange', linestyle='--', alpha=0.7, linewidth=2, label=f'x = 20 cm → {fraction_20cm:.2%}')
ax1.scatter([5, 20], [fraction_5cm, fraction_20cm], color=['red', 'orange'], s=150, zorder=5, edgecolors='black', linewidths=1.5)
ax1.set_xlabel('Épaisseur d\'eau traversée (cm)', fontsize=13, fontweight='bold')
ax1.set_ylabel(r'Fraction transmise $I/I_0$', fontsize=13, fontweight='bold')
ax1.set_title('Loi de Beer-Lambert — Échelle linéaire', fontsize=14, fontweight='bold')
ax1.grid(True, alpha=0.3)
ax1.legend(fontsize=11, loc='upper right')
ax1.set_xlim(0, 30)
ax1.set_ylim(0, 1.05)

# Graphique 2 : Échelle logarithmique
ax2.semilogy(x_range, I_sur_I0, 'b-', linewidth=2.5, label=r'$I/I_0 = e^{-\mu x}$')
ax2.axvline(5, color='red', linestyle='--', alpha=0.7, linewidth=2, label=f'x = 5 cm → {fraction_5cm:.1%}')
ax2.axvline(20, color='orange', linestyle='--', alpha=0.7, linewidth=2, label=f'x = 20 cm → {fraction_20cm:.2%}')
ax2.scatter([5, 20], [fraction_5cm, fraction_20cm], color=['red', 'orange'], s=150, zorder=5, edgecolors='black', linewidths=1.5)
ax2.set_xlabel('Épaisseur d\'eau traversée (cm)', fontsize=13, fontweight='bold')
ax2.set_ylabel(r'Fraction transmise $I/I_0$ (log)', fontsize=13, fontweight='bold')
ax2.set_title('Loi de Beer-Lambert — Échelle logarithmique', fontsize=14, fontweight='bold')
ax2.grid(True, alpha=0.3, which='both')
ax2.legend(fontsize=11, loc='upper right')
ax2.set_xlim(0, 30)

fig.suptitle('Atténuation des rayons X de 60 keV dans l\'eau', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Résultats — Coefficient d'atténuation
#
# D'après la base de données **NIST XCOM** pour l'eau pure (H₂O) à 60 keV :
#
# **Tableau 1 : Coefficient d'atténuation de l'eau à 60 keV**
#
# | Paramètre | Symbole | Valeur |
# |:----------|:--------|:-------|
# | Coefficient d'atténuation massique | $\mu/\rho$ | 0.2059 cm²/g |
# | Masse volumique de l'eau | $\rho$ | 1.0 g/cm³ |
# | **Coefficient d'atténuation linéaire** | **$\mu$** | **0.2059 cm⁻¹** |
#
# #### Loi de Beer-Lambert
#
# La loi de Beer-Lambert décrit l'atténuation exponentielle des rayons X :
#
# $$I = I_0 \cdot e^{-\mu x}$$
#
# où $I_0$ est l'intensité initiale, $I$ l'intensité transmise, $\mu$ le coefficient d'atténuation, et $x$ l'épaisseur traversée.
#
# **Tableau 2 : Fractions transmises pour différentes épaisseurs d'eau**
#
# | Épaisseur | Fraction transmise ($I/I_0$) | Atténuation |
# |:----------|:----------------------------|:------------|
# | **5 cm** | 0.3588 (35.88%) | **64.12%** |
# | **20 cm** | 0.0176 (1.76%) | **98.24%** |
#
#
# **Observation:** L'atténuation est **exponentielle** — après 20 cm d'eau, moins de 2% du signal subsiste.

# %% [markdown]
# <div style="height: 50px;"></div>
# <div style="position: relative; margin: 30px 0;">
#     <div style="height: 3px; background: linear-gradient(90deg, transparent, #2196F3, #E91E63, #2196F3, transparent); border-radius: 3px;"></div>
#     <div style="position: absolute; top: 50%; left: 50%; transform: translate(-50%, -50%); background: #1e1e1e; padding: 0 20px;">
#         <span style="color: #E91E63; font-size: 18px; font-weight: bold; letter-spacing: 3px;">✦ ✦ ✦</span>
#     </div>
# </div>
# <br />
#
# <a id="q2"></a>
#
# <div style="
#     background: linear-gradient(135deg, #0f0c29 0%, #302b63 100%);
#     padding: 22px 30px;
#     border-radius: 12px;
#     margin: 10px 0 20px 0;
#     box-shadow: 0 8px 25px rgba(15, 12, 41, 0.5);
#     border: 1px solid rgba(233, 30, 99, 0.3);
#     border-left: 5px solid #E91E63;
# ">
#     <div style="display: flex; align-items: center; gap: 15px;">
#         <div style="
#             background: linear-gradient(135deg, #E91E63, #AD1457);
#             color: white;
#             width: 45px; height: 45px;
#             border-radius: 50%;
#             display: flex; align-items: center; justify-content: center;
#             font-size: 20px; font-weight: bold;
#             box-shadow: 0 4px 15px rgba(233, 30, 99, 0.4);
#             flex-shrink: 0;
#         ">2</div>
#         <h2 style="color: white; margin: 0; font-size: 22px; font-weight: 300; letter-spacing: 1px;">Rétroprojection simple — Laminogramme</h2>
#     </div>
# </div>
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #E91E63; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# **Énoncé :** *En utilisant le code fourni (ou pas), créer une rétroprojection simple, aussi appelée laminogramme, des données de projection fournies. Notez qu'une approche par slicing pourrait accélérer votre algorithme. Votre code utilisera la méthode du plus proche voisin pour déterminer la valeur de projection à utiliser (le rayon passant par la source et le voxel d'intérêt n'aboutit pas nécessairement au centre des pixels du détecteur). Une fois que vous aurez accès au fantôme numérique, comparez-le à la reconstruction. Qualitativement, quelles différences observez-vous entre l'image reconstruite et l'image de référence (fantôme) ?*
#
# </div>
#
# <div style="background-color: #1a1a2e; color: #a8d0e6; border-left: 5px solid #FFB300; padding: 12px; border-radius: 5px; margin-top: 10px; font-size: 0.9em;">
#
# 💡 **Approche suggérée :** Méthode *voxel-driven* — pour chaque voxel de la grille, sommer la contribution de chaque projection en identifiant le pixel détecteur correspondant par plus proche voisin.
#
# </div>

# %% [markdown]
# ## Approche — Rétroprojection voxel-driven
#
# L'algorithme de rétroprojection simple (ou laminogramme) est la méthode la plus intuitive pour reconstruire une image CT. Pour chaque voxel $(i, j)$ de la grille de reconstruction, on calcule sa projection sur le détecteur pour chaque angle $\theta$ et on somme les valeurs mesurées :
#
# $$g(x, y) = \sum_{\theta} p_\theta(x \cos\theta + y \sin\theta)$$
#
# L'identification du pixel détecteur se fait par plus proche voisin : $\text{idx} = \text{round}(\text{center}_{\text{det}} + t / p_{\text{size}})$.
#
# **Complexité algorithmique :** $\mathcal{O}(N_{\text{proj}} \times N_{\text{vox}}^2)$ — triple boucle imbriquée, très lent pour de grandes grilles.
#
# **Tableau 3 : Caractéristiques du laminogramme**
#
# | Aspect | Description |
# |:-------|:------------|
# | **Méthode** | Voxel-driven (parcours de la grille de reconstruction) |
# | **Interpolation** | Plus proche voisin sur le détecteur |
# | **Avantages** | Simple à implémenter, intuitif |
# | **Inconvénients** | Très lent, qualité d'image médiocre (pas de filtrage) |

# %%
def laminogram_simple(sinogram, angles, nbvox=96, voxsize=0.4, pixsize=0.165):
    """
    Rétroprojection simple (laminogramme) - méthode voxel-driven

    Pour chaque voxel, projeter sur toutes les directions et sommer.
    """
    nbprj, nbpix = sinogram.shape
    image = np.zeros((nbvox, nbvox))

    center = (nbvox - 1) / 2.0
    det_center = (nbpix - 1) / 2.0

    # Boucle sur chaque voxel
    for j in range(nbvox):
        if j % 20 == 0:
            print(f"  Progression : {j}/{nbvox} lignes ({100*j/nbvox:.0f}%)", end='\r')
        for i in range(nbvox):
            # Position du voxel dans le repère monde (cm)
            x = (i - center) * voxsize
            y = (j - center) * voxsize

            # Somme sur toutes les projections
            for ia, angle in enumerate(angles):
                # Projection sur le détecteur : t = x·cos(θ) + y·sin(θ)
                t = x * np.cos(angle) + y * np.sin(angle)

                # Index du pixel détecteur correspondant
                idx_det = det_center + t / pixsize

                # Plus proche voisin
                idx_det_int = int(np.round(idx_det))

                # Vérifier que l'index est valide
                if 0 <= idx_det_int < nbpix:
                    image[j, i] += sinogram[ia, idx_det_int]

    print(f"  Progression : {nbvox}/{nbvox} lignes (100%)    ")
    return image

# Paramètres de reconstruction
nbvox = 96         # Nombre de voxels par dimension
voxsize = 0.4      # Taille d'un voxel (cm)
pixsize = 0.165    # Taille d'un pixel du détecteur (cm)

# Reconstruction par laminogramme
print("Reconstruction par laminogramme (rétroprojection simple)...")
t_start = time.time()
image_lam = laminogram_simple(sinogram_password, angles, nbvox, voxsize, pixsize)
t_end = time.time()
temps_lam = t_end - t_start

print(f"Temps de calcul : {temps_lam:.2f} secondes")
# Out:
# Reconstruction par laminogramme (rétroprojection simple)...
#   Progression : 96/96 lignes (100%)
# Temps de calcul : 15.71 secondes

# %% [markdown]
# ## Visualisation du laminogramme
#
# <div style="background-color: #1a1a2e; color: #a8d0e6; border-left: 5px solid #E91E63; padding: 12px 16px; border-radius: 5px; margin: 10px 0; font-size: 0.9em;">
# Le graphique ci-dessous présente l'image reconstruite par rétroprojection simple. On observe les <strong>artefacts radiaux caractéristiques</strong> (motif en étoile) et le <strong>flou important</strong> qui dégradent fortement la qualité de l'image.
# </div>

# %%
# Visualisation du résultat
fig, ax = plt.subplots(1, 1, figsize=(10, 9))

vmin, vmax = np.percentile(image_lam, [1, 99])
im = ax.imshow(image_lam, cmap='gray', interpolation='nearest', vmin=vmin, vmax=vmax)
ax.set_title(f'Laminogramme (rétroprojection simple)\nTemps: {temps_lam:.1f}s', 
             fontsize=14, fontweight='bold')
ax.set_xlabel('x (pixel)', fontsize=12)
ax.set_ylabel('y (pixel)', fontsize=12)

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im, cax=cax, label='Intensité')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #252526; color: white; border-left: 5px solid #E91E63; padding: 15px; border-radius: 5px; margin-top: 20px;">
#
# <strong style="color: #F8BBD0; font-size: 1.1em;">Analyse du résultat :</strong>
# <br><br>
#
# L'image reconstruite par **rétroprojection simple** présente plusieurs défauts majeurs :
#
# 1. **Flou important** : contours mal définis, structures anatomiques difficilement identifiables
# 2. **Motif en étoile** : artefacts radiaux caractéristiques de la rétroprojection non filtrée
# 3. **Fond diffus en $1/r$** : accumulation des contributions hors-objet qui noie les détails
#
# **Cause fondamentale :** En l'absence de filtrage passe-haut, la rétroprojection simple calcule $g(x,y) = \int_0^\pi p_\theta(x\cos\theta + y\sin\theta)\,d\theta$, ce qui correspond à la transformation de Radon inverse **non filtrée**. Pour une reconstruction correcte, il faut appliquer un **filtre rampe** $|u|$ (Q3-Q4) ou utiliser le **théorème de Fourier Slice** (Q6).
#
# **Comparaison au fantôme numérique :** Par rapport au fantôme original (accessible via le mot de passe reconstruit), le laminogramme présente un **flou général** qui empêche de distinguer les structures fines. Les artefacts en étoile superposent un motif radial inexistant dans le fantôme. La **perte de contraste** est sévère : les différences d'atténuation entre régions sont estompées par le fond diffus en $1/r$. Les petites structures (détails sub-millimétriques) sont **complètement noyées** dans le bruit de rétroprojection.
#
# **Conclusion :** Le laminogramme est **inadapté** pour l'usage clinique — intérêt uniquement pédagogique pour illustrer la nécessité du filtrage.
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div>
# <div style="position: relative; margin: 30px 0;">
#     <div style="height: 3px; background: linear-gradient(90deg, transparent, #9C27B0, #2196F3, #9C27B0, transparent); border-radius: 3px;"></div>
#     <div style="position: absolute; top: 50%; left: 50%; transform: translate(-50%, -50%); background: #1e1e1e; padding: 0 20px;">
#         <span style="color: #9C27B0; font-size: 18px; font-weight: bold; letter-spacing: 3px;">✦ ✦ ✦</span>
#     </div>
# </div>
# <br />
#
# <a id="q3"></a>
#
# <div style="
#     background: linear-gradient(135deg, #0f0c29 0%, #302b63 100%);
#     padding: 22px 30px;
#     border-radius: 12px;
#     margin: 10px 0 20px 0;
#     box-shadow: 0 8px 25px rgba(15, 12, 41, 0.5);
#     border: 1px solid rgba(156, 39, 176, 0.3);
#     border-left: 5px solid #9C27B0;
# ">
#     <div style="display: flex; align-items: center; gap: 15px;">
#         <div style="
#             background: linear-gradient(135deg, #9C27B0, #6A1B9A);
#             color: white;
#             width: 45px; height: 45px;
#             border-radius: 50%;
#             display: flex; align-items: center; justify-content: center;
#             font-size: 20px; font-weight: bold;
#             box-shadow: 0 4px 15px rgba(156, 39, 176, 0.4);
#             flex-shrink: 0;
#         ">3</div>
#         <h2 style="color: white; margin: 0; font-size: 22px; font-weight: 300; letter-spacing: 1px;">Filtrage passe-haut du sinogramme</h2>
#     </div>
# </div>
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #9C27B0; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# **Énoncé :** *En utilisant la librairie `numpy.fft`, implémentez le filtre passe-haut proposé pour filtrer le sinogramme une projection à la fois. Affichez et sauvegardez l'image du sinogramme filtré. Qualitativement, quelles sont les principales différences entre le sinogramme fourni et filtré ?*
#
# </div>
#
# ### Rappel théorique — Algorithme de filtrage
#
# L'opération de filtrage dans le domaine fréquentiel s'effectue en trois étapes :
#
# $$P(u) = \mathcal{F}[p(t)] \qquad \longrightarrow \qquad P_f(u) = P(u) \times |u| \qquad \longrightarrow \qquad p_f(t) = \mathcal{F}^{-1}[P(u) \times |u|]$$
#
# Le filtre $f(u) = |u|$ amplifie les hautes fréquences spatiales, ce qui compense l'excès de basses fréquences introduit par la rétroprojection.
#
# <div style="background-color: #1a1a2e; color: #a8d0e6; border-left: 5px solid #FFB300; padding: 12px; border-radius: 5px; margin-top: 10px; font-size: 0.9em;">
#
# 💡 **Indices :** Lisez bien à quoi sert la fonction `fftshift` et n'oubliez pas que $p(t)$ est une fonction réelle.
#
# </div>

# %%
def filter_projection_ramp(projection):
    """
    Applique le filtre passe-haut |u| (filtre rampe) à une projection 1D
    
    Étapes :
      1. Transformée de Fourier 1D : P(u) = FFT[p(t)]
      2. Application du filtre rampe : P_f(u) = P(u) × |u|
      3. Transformée inverse : p_f(t) = IFFT[P_f(u)]
    """
    N = len(projection)
    
    # 1. Transformée de Fourier 1D
    P = fft(projection)
    
    # 2. Création du filtre rampe |u|
    freqs = fftfreq(N)  # Fréquences normalisées [-0.5, 0.5]
    ramp_filter = np.abs(freqs)
    
    # 3. Application du filtre dans le domaine fréquentiel
    P_filtered = P * ramp_filter
    
    # 4. Transformée inverse pour revenir dans le domaine spatial
    projection_filtered = ifft(P_filtered)
    
    # 5. Retourner la partie réelle (le signal est réel)
    return np.real(projection_filtered)


def filter_sinogram_ramp(sinogram):
    """
    Filtre toutes les projections d'un sinogramme avec le filtre rampe
    """
    nbprj, nbpix = sinogram.shape
    sinogram_filtered = np.zeros_like(sinogram)
    
    for i in range(nbprj):
        sinogram_filtered[i] = filter_projection_ramp(sinogram[i])
    
    return sinogram_filtered

# Application du filtre
print("Filtrage du sinogramme avec le filtre rampe |u|...")
t_start = time.time()
sinogram_filtered = filter_sinogram_ramp(sinogram_password)
t_end = time.time()
temps_filtre = t_end - t_start
print(f"Temps de filtrage : {temps_filtre:.3f} secondes")
# Out:
# Filtrage du sinogramme avec le filtre rampe |u|...
# Temps de filtrage : 0.021 secondes

# %% [markdown]
# ## Principe du filtrage rampe
#
# Le **filtre rampe** (ou filtre $|u|$) est un filtre passe-haut essentiel en tomographie. Il compense la décroissance en $1/r$ du laminogramme en appliquant à chaque projection :
#
# $$p_{\text{filtré}}(t) = \mathcal{F}^{-1}\left[\mathcal{F}[p(t)] \cdot |u|\right]$$
#
# Pour chaque projection du sinogramme, on effectue :
#
# 1. **Transformée de Fourier** : $P(u) = \text{FFT}[p(t)]$
# 2. **Application du filtre** : $P_{\text{filtré}}(u) = P(u) \times |u|$
# 3. **Transformée inverse** : $p_{\text{filtré}}(t) = \text{Re}[\text{IFFT}[P_{\text{filtré}}(u)]]$
#
# Le filtre $H(u) = |u|$ amplifie linéairement les hautes fréquences spatiales. Ses propriétés :
#
# **Tableau 4 : Propriétés du filtre rampe**
#
# | Aspect | Description |
# |:-------|:------------|
# | **Type** | Passe-haut |
# | **$H(0) = 0$** | Supprime la composante continue (biais) |
# | **$H(u) \propto u$** | Amplifie linéairement les hautes fréquences |
# | **Coût** | $\mathcal{O}(N_{\text{proj}} \times N_{\text{pix}} \log N_{\text{pix}})$ |

# %%
# Visualisation comparative
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# Ligne 1 : Sinogrammes brut et filtré
im0 = axes[0, 0].imshow(sinogram_password, aspect='auto', cmap='inferno', interpolation='nearest')
axes[0, 0].set_title('Sinogramme brut', fontsize=13, fontweight='bold')
axes[0, 0].set_xlabel('Détecteur (pixel)')
axes[0, 0].set_ylabel('Projection')
plt.colorbar(im0, ax=axes[0, 0], label=r'$\ln(I_0/I)$')

im1 = axes[0, 1].imshow(sinogram_filtered, aspect='auto', cmap='inferno', interpolation='nearest')
axes[0, 1].set_title('Sinogramme filtré (|u|)', fontsize=13, fontweight='bold')
axes[0, 1].set_xlabel('Détecteur (pixel)')
axes[0, 1].set_ylabel('Projection')
plt.colorbar(im1, ax=axes[0, 1], label=r'$\ln(I_0/I)$')

# Différence
diff = sinogram_filtered - sinogram_password
im2 = axes[0, 2].imshow(diff, aspect='auto', cmap='RdBu_r', interpolation='nearest')
axes[0, 2].set_title('Différence (filtré - brut)', fontsize=13, fontweight='bold')
axes[0, 2].set_xlabel('Détecteur (pixel)')
axes[0, 2].set_ylabel('Projection')
plt.colorbar(im2, ax=axes[0, 2], label=r'$\Delta\ln(I_0/I)$')

# Ligne 2 : Comparaison d'une projection individuelle (projection n°360)
proj_idx = 360
projection_brute = sinogram_password[proj_idx]
projection_filtree = sinogram_filtered[proj_idx]

axes[1, 0].plot(projection_brute, 'b-', linewidth=2, label='Brut')
axes[1, 0].set_title(f'Projection #{proj_idx} — Brut', fontsize=13, fontweight='bold')
axes[1, 0].set_xlabel('Position détecteur (pixel)')
axes[1, 0].set_ylabel(r'$\ln(I_0/I)$')
axes[1, 0].grid(alpha=0.3)
axes[1, 0].legend()

axes[1, 1].plot(projection_filtree, 'r-', linewidth=2, label='Filtré')
axes[1, 1].set_title(f'Projection #{proj_idx} — Filtré', fontsize=13, fontweight='bold')
axes[1, 1].set_xlabel('Position détecteur (pixel)')
axes[1, 1].set_ylabel('Amplitude')
axes[1, 1].grid(alpha=0.3)
axes[1, 1].legend()

# Spectres de Fourier (module)
P_brut = np.abs(fftshift(fft(projection_brute)))
P_filtre = np.abs(fftshift(fft(projection_filtree)))
freqs_plot = fftshift(fftfreq(len(projection_brute)))

axes[1, 2].semilogy(freqs_plot, P_brut, 'b-', linewidth=2, alpha=0.7, label='Brut')
axes[1, 2].semilogy(freqs_plot, P_filtre, 'r-', linewidth=2, alpha=0.7, label='Filtré')
axes[1, 2].set_title('Spectre de Fourier (module)', fontsize=13, fontweight='bold')
axes[1, 2].set_xlabel('Fréquence normalisée')
axes[1, 2].set_ylabel('|FFT| (log)')
axes[1, 2].grid(alpha=0.3, which='both')
axes[1, 2].legend()
axes[1, 2].set_xlim(-0.5, 0.5)

fig.suptitle('Filtrage passe-haut du sinogramme',
             fontsize=16, fontweight='bold', y=0.995)
plt.tight_layout()
plt.show()

fig.savefig("sinogramme_filtre_Q3.png", dpi=200, bbox_inches="tight")
print("Image sauvegardée : sinogramme_filtre_Q3.png")
# Out:
# Image sauvegardée : sinogramme_filtre_Q3.png

# %% [markdown]
# <div style="background-color: #252526; color: white; border-left: 5px solid #9C27B0; padding: 15px; border-radius: 5px; margin-top: 20px;">
#
# <strong style="color: #CE93D8; font-size: 1.1em;">Analyse du filtrage :</strong>
# <br><br>
#
# **Dans le domaine spatial :**
# - Contraste rehaussé : structures plus nettes
# - Suppression du biais de basses fréquences (fond sombre éliminé)
# - Valeurs négatives : le filtre biphasé introduit des oscillations (overshoot/undershoot)
# - Accentuation des contours : transitions brusques amplifiées
#
# **Dans le domaine fréquentiel :**
# - Basses fréquences ($|u| \to 0$) : fortement atténuées → suppression du fond uniforme
# - Hautes fréquences ($|u| \to 0.5$) : amplifiées linéairement → détails fins mis en évidence
# - Compromis : amélioration de la netteté au prix d'une amplification du bruit
#
# **Impact sur la reconstruction :**
# Sans ce filtrage, la rétroprojection donne un laminogramme flou (Q2). Avec le filtre rampe, la **FBP** (Filtered Back-Projection) devient possible → Question 4.
#
# Le terme $|u|$ compense la décroissance en $1/r$ de la densité d'échantillonnage en coordonnées polaires :
#
# $$f(x,y) = \int_0^\pi \left[ \int_{-\infty}^\infty P_\theta(u) |u| e^{2\pi i u t}\, du \right] d\theta$$
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div>
# <div style="position: relative; margin: 30px 0;">
#     <div style="height: 3px; background: linear-gradient(90deg, transparent, #00BCD4, #E91E63, #00BCD4, transparent); border-radius: 3px;"></div>
#     <div style="position: absolute; top: 50%; left: 50%; transform: translate(-50%, -50%); background: #1e1e1e; padding: 0 20px;">
#         <span style="color: #00BCD4; font-size: 18px; font-weight: bold; letter-spacing: 3px;">✦ ✦ ✦</span>
#     </div>
# </div>
# <br />
#
# <a id="q4"></a>
#
# <div style="
#     background: linear-gradient(135deg, #0f0c29 0%, #302b63 100%);
#     padding: 22px 30px;
#     border-radius: 12px;
#     margin: 10px 0 20px 0;
#     box-shadow: 0 8px 25px rgba(15, 12, 41, 0.5);
#     border: 1px solid rgba(0, 188, 212, 0.3);
#     border-left: 5px solid #00BCD4;
# ">
#     <div style="display: flex; align-items: center; gap: 15px;">
#         <div style="
#             background: linear-gradient(135deg, #00BCD4, #00838F);
#             color: white;
#             width: 45px; height: 45px;
#             border-radius: 50%;
#             display: flex; align-items: center; justify-content: center;
#             font-size: 20px; font-weight: bold;
#             box-shadow: 0 4px 15px rgba(0, 188, 212, 0.4);
#             flex-shrink: 0;
#         ">4</div>
#         <h2 style="color: white; margin: 0; font-size: 22px; font-weight: 300; letter-spacing: 1px;">Rétroprojection filtrée (FBP)</h2>
#     </div>
# </div>
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #00BCD4; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# **Énoncé :** *Ayant en main le sinogramme filtré, effectuez une rétroprojection filtrée, en récupérant idéalement le code précédent du laminogramme. Comparez l'image obtenue avec le fantôme. Quelles différences observez-vous ? Où sont situées les erreurs et que diriez-vous de la fréquence spatiale des erreurs ?*
#
# </div>

# %% [markdown]
# ## Principe
#
# <div style="background-color: #1a1a2e; color: #a8d0e6; border-left: 5px solid #00BCD4; padding: 12px 16px; border-radius: 5px; margin: 10px 0; font-size: 0.9em;">
# La <strong>rétroprojection filtrée</strong> (FBP) combine le filtrage rampe (Q3) et la rétroprojection (Q2) : on réutilise <code>laminogram_simple()</code> mais en lui passant le <strong>sinogramme filtré</strong> plutôt que le sinogramme brut. Le filtre $|u|$ compense la décroissance en $1/r$ inhérente au laminogramme.
# </div>

# %%
# Reconstruction FBP = rétroprojection du sinogramme filtré
print("Reconstruction par FBP (Filtered Back-Projection)...")
t_start = time.time()
image_fbp = laminogram_simple(sinogram_filtered, angles, nbvox, voxsize, pixsize)
t_end = time.time()
temps_fbp = t_end - t_start

print(f"Temps de reconstruction FBP : {temps_fbp:.2f} secondes")
# Out:
# Reconstruction par FBP (Filtered Back-Projection)...
#   Progression : 96/96 lignes (100%)
# Temps de reconstruction FBP : 16.81 secondes

# %% [markdown]
# ## Principe — Filtered Back-Projection (FBP)
#
# La **rétroprojection filtrée** est la méthode standard en tomographie clinique. Elle combine le filtrage du sinogramme (Q3) et la rétroprojection (Q2). Concrètement, on réutilise la même fonction `laminogram_simple()` mais en lui passant le **sinogramme filtré** au lieu du sinogramme brut :
#
# $$f(x,y) = \int_0^\pi \left[\int_{-\infty}^\infty P_\theta(u) |u| e^{2\pi i u (x\cos\theta + y\sin\theta)} du\right] d\theta$$
#
# **Tableau 5 : Comparaison laminogramme vs FBP**
#
# | Méthode | Sinogramme utilisé | Qualité | Vitesse |
# |:--------|:-------------------|:--------|:--------|
# | **Laminogramme** (Q2) | Brut (non filtré) | Floue, inutilisable | Lente |
# | **FBP** (Q4) | Filtré (rampe $\|u\|$) | Nette, diagnostique | Lente |
#
# Le filtre rampe $|u|$ compense la décroissance en $1/r$ de la densité d'échantillonnage en coordonnées polaires.

# %%
# Visualisation comparative
fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# Laminogramme
vmin1, vmax1 = np.percentile(image_lam, [1, 99])
im0 = axes[0].imshow(image_lam, cmap='gray', interpolation='nearest', vmin=vmin1, vmax=vmax1)
axes[0].set_title('Rétroprojection simple (Q2)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('x (pixel)')
axes[0].set_ylabel('y (pixel)')
divider0 = make_axes_locatable(axes[0])
cax0 = divider0.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im0, cax=cax0, label=r'$\mu$ (cm$^{-1}$)')

# FBP
vmin2, vmax2 = np.percentile(image_fbp, [1, 99])
im1 = axes[1].imshow(image_fbp, cmap='gray', interpolation='nearest', vmin=vmin2, vmax=vmax2)
axes[1].set_title('Rétroprojection filtrée / FBP (Q4)', fontsize=14, fontweight='bold')
axes[1].set_xlabel('x (pixel)')
axes[1].set_ylabel('y (pixel)')
divider1 = make_axes_locatable(axes[1])
cax1 = divider1.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im1, cax=cax1, label=r'$\mu$ (cm$^{-1}$)')

fig.suptitle('Comparaison : Laminogramme vs FBP', 
             fontsize=16, fontweight='bold', y=0.98)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #252526; color: white; border-left: 5px solid #00BCD4; padding: 15px; border-radius: 5px; margin-top: 20px;">
#
# <strong style="color: #B2EBF2; font-size: 1.1em;">Analyse — Comparaison Laminogramme vs FBP :</strong>
# <br><br>
#
# **Améliorations majeures :**
# - Contraste nettement amélioré, structures anatomiques clairement définies
# - Suppression du halo flou et du motif en étoile
# - Fond proche de zéro (pas de biais de basses fréquences)
# - Image **diagnostiquable** (contrairement au laminogramme)
#
# **Erreurs résiduelles :**
# - Artefacts en rayons subtils près des bords (périphérie de l'image)
# - Oscillations de Gibbs aux transitions brusques (overshoot/undershoot)
# - Bruit haute fréquence dans les zones homogènes (granularité)
#
# **Fréquence spatiale des erreurs :**
# Les erreurs résiduelles sont de **hautes fréquences**, causées par l'amplification du bruit par le filtre $|u|$. En pratique, on utilise des **filtres fenêtrés** (Hamming, Hann, Shepp-Logan) : $H(u) = |u| \times W(u)$, où $W(u)$ atténue les très hautes fréquences.
#
# **Comparaison au fantôme numérique :** Par rapport au fantôme original, la FBP **récupère les contours nets** des structures anatomiques. Les bords des objets sont bien localisés spatialement, contrairement au laminogramme. Cependant, on observe une **présence résiduelle d'artefacts haute fréquence aux bords**, notamment des oscillations de Gibbs aux interfaces de fort contraste (transitions abruptes de coefficient d'atténuation). Les **fréquences spatiales élevées** sont les plus affectées : le filtre rampe $|u|$ amplifie le bruit aux hautes fréquences, ce qui introduit une granularité absente du fantôme idéal. Les zones de contraste uniforme dans le fantôme présentent un léger bruit résiduel dans la reconstruction FBP.
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div>
# <div style="position: relative; margin: 30px 0;">
#     <div style="height: 3px; background: linear-gradient(90deg, transparent, #FF9800, #2196F3, #FF9800, transparent); border-radius: 3px;"></div>
#     <div style="position: absolute; top: 50%; left: 50%; transform: translate(-50%, -50%); background: #1e1e1e; padding: 0 20px;">
#         <span style="color: #FF9800; font-size: 18px; font-weight: bold; letter-spacing: 3px;">✦ ✦ ✦</span>
#     </div>
# </div>
# <br />
#
# <a id="q5"></a>
#
# <div style="
#     background: linear-gradient(135deg, #0f0c29 0%, #302b63 100%);
#     padding: 22px 30px;
#     border-radius: 12px;
#     margin: 10px 0 20px 0;
#     box-shadow: 0 8px 25px rgba(15, 12, 41, 0.5);
#     border: 1px solid rgba(255, 152, 0, 0.3);
#     border-left: 5px solid #FF9800;
# ">
#     <div style="display: flex; align-items: center; gap: 15px;">
#         <div style="
#             background: linear-gradient(135deg, #FF9800, #E65100);
#             color: white;
#             width: 45px; height: 45px;
#             border-radius: 50%;
#             display: flex; align-items: center; justify-content: center;
#             font-size: 20px; font-weight: bold;
#             box-shadow: 0 4px 15px rgba(255, 152, 0, 0.4);
#             flex-shrink: 0;
#         ">5</div>
#         <h2 style="color: white; margin: 0; font-size: 22px; font-weight: 300; letter-spacing: 1px;">Interpolation linéaire sur le détecteur</h2>
#     </div>
# </div>
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #FF9800; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# **Énoncé :** *Tentons d'améliorer la qualité d'image davantage. Écrivez une nouvelle fonction dans `geometry.py` qui permet d'ajouter une valeur d'atténuation plus précise à chaque voxel lors de la rétroprojection. Au lieu d'identifier le pixel plus proche voisin sur le détecteur de radiation, utilisez l'interpolation linéaire entre deux pixels adjacents sur le détecteur. Comment l'image s'est-elle améliorée ? Pour référence future, enregistrez le temps de reconstruction total.*
#
# </div>

# %% [markdown]
# ## Principe — Interpolation linéaire
#
# Conformément à l'énoncé, une nouvelle fonction `get_proj_value_linear()` a été ajoutée au fichier **`geometry.py`**. Elle remplace le plus proche voisin par une interpolation linéaire entre les deux pixels adjacents du détecteur. Si la projection d'un voxel tombe à l'indice $t = 42.7$ :
#
# **Tableau 6 : Interpolation PPV vs linéaire**
#
# | Méthode | Valeur utilisée | Fonction (`geometry.py`) |
# |:--------|:----------------|:--------------------------|
# | Plus proche voisin (Q2, Q4) | `sino[43]` | `get_proj_value_nearest()` |
# | Interpolation linéaire (Q5) | $0.3 \times \texttt{sino[42]} + 0.7 \times \texttt{sino[43]}$ | **`get_proj_value_linear()`** |
#
# <div style="background-color: #1a1a2e; color: #a8d0e6; border-left: 5px solid #FF9800; padding: 12px 16px; border-radius: 5px; margin: 10px 0; font-size: 0.9em;">
# 💡 Cette approche réduit les <strong>artefacts de discrétisation</strong> et lisse les transitions abruptes entre pixels voisins, pour un coût computationnel quasi nul. La fonction est définie dans <code>geometry.py</code> et importée ici comme <code>geo.get_proj_value_linear()</code>.
# </div>

# %%
# Question 5 — FBP avec interpolation linéaire (get_proj_value_linear dans geometry.py)
import importlib, sys, os
sys.path.insert(0, os.path.abspath('.'))
import geometry as geo
importlib.reload(geo)   # S'assure d'avoir la version à jour avec get_proj_value_linear()

def backproject_linear_interp(sinogram, angles, nbvox=96, voxsize=0.4, pixsize=0.165):
    """
    Rétroprojection filtrée avec interpolation linéaire (Q5).

    Utilise geo.get_proj_value_linear() (geometry.py) au lieu du plus proche
    voisin pour obtenir une valeur d'atténuation plus précise à chaque voxel.
    """
    nbprj, nbpix = sinogram.shape
    image = np.zeros((nbvox, nbvox))
    center = (nbvox - 1) / 2.0
    det_center = (nbpix - 1) / 2.0

    for j in range(nbvox):
        if j % 20 == 0:
            print(f"  Progression : {j}/{nbvox} lignes ({100*j/nbvox:.0f}%)", end='\r')
        for i in range(nbvox):
            x = (i - center) * voxsize
            y = (j - center) * voxsize

            for a_idx, phi in enumerate(angles):
                t = x * np.cos(phi) + y * np.sin(phi)
                t_pixel = t / pixsize + det_center

                # Interpolation linéaire via geometry.py (Q5)
                image[j, i] += geo.get_proj_value_linear(sinogram[a_idx], t_pixel)

    print(f"  Progression : {nbvox}/{nbvox} lignes (100%)    ")
    return image


# Reconstruction FBP avec interpolation linéaire
t_start = time.time()
image_fbp_linear = backproject_linear_interp(sinogram_filtered, angles, nbvox, voxsize, pixsize)
t_end = time.time()
temps_fbp_linear = t_end - t_start
temps_fbp_q5 = temps_fbp_linear

print(f"Temps de reconstruction : {temps_fbp_linear:.2f} s")

# --- Visualisation : PPV vs interpolation linéaire ---
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

vmin1, vmax1 = np.percentile(image_fbp, [1, 99])
im0 = axes[0].imshow(image_fbp, cmap='gray', interpolation='nearest', vmin=vmin1, vmax=vmax1)
axes[0].set_title(f'FBP — Plus proche voisin\n(Q4, temps: {temps_fbp:.1f}s)', fontsize=13, fontweight='bold')
axes[0].set_xlabel('x (pixel)')
axes[0].set_ylabel('y (pixel)')
divider0 = make_axes_locatable(axes[0])
cax0 = divider0.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im0, cax=cax0, label=r'$\mu$ (cm$^{-1}$)')

vmin2, vmax2 = np.percentile(image_fbp_linear, [1, 99])
im1 = axes[1].imshow(image_fbp_linear, cmap='gray', interpolation='nearest', vmin=vmin2, vmax=vmax2)
axes[1].set_title(f'FBP — Interpolation linéaire (geometry.py)\n(Q5, temps: {temps_fbp_linear:.1f}s)', fontsize=13, fontweight='bold')
axes[1].set_xlabel('x (pixel)')
axes[1].set_ylabel('y (pixel)')
divider1 = make_axes_locatable(axes[1])
cax1 = divider1.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im1, cax=cax1, label=r'$\mu$ (cm$^{-1}$)')

diff = image_fbp_linear - image_fbp
im2 = axes[2].imshow(diff, cmap='RdBu_r', interpolation='nearest')
axes[2].set_title('Différence\n(linéaire - plus proche voisin)', fontsize=13, fontweight='bold')
axes[2].set_xlabel('x (pixel)')
axes[2].set_ylabel('y (pixel)')
divider2 = make_axes_locatable(axes[2])
cax2 = divider2.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im2, cax=cax2, label=r'$\Delta\mu$ (cm$^{-1}$)')

fig.suptitle('Question 5 — Impact de l\'interpolation linéaire sur la FBP (geo.get_proj_value_linear)',
             fontsize=16, fontweight='bold', y=0.98)
plt.tight_layout()
plt.show()

# --- Zoom ROI central ---
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

roi_size = 30
center_idx = nbvox // 2
roi_slice = (slice(center_idx - roi_size//2, center_idx + roi_size//2),
             slice(center_idx - roi_size//2, center_idx + roi_size//2))

roi_ppv = image_fbp[roi_slice]
roi_linear = image_fbp_linear[roi_slice]

im0 = axes[0].imshow(roi_ppv, cmap='gray', interpolation='nearest')
axes[0].set_title('ROI — Plus proche voisin', fontsize=13, fontweight='bold')
plt.colorbar(im0, ax=axes[0], label=r'$\mu$ (cm$^{-1}$)')

im1 = axes[1].imshow(roi_linear, cmap='gray', interpolation='nearest')
axes[1].set_title('ROI — Interpolation linéaire (geometry.py)', fontsize=13, fontweight='bold')
plt.colorbar(im1, ax=axes[1], label=r'$\mu$ (cm$^{-1}$)')

fig.suptitle('Zoom sur région centrale (30×30 pixels)', fontsize=15, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
#   Progression : 96/96 lignes (100%)
# Temps de reconstruction : 11.64 s

# %% [markdown]
# <div style="background-color: #252526; color: white; border-left: 5px solid #FF9800; padding: 15px; border-radius: 5px; margin-top: 20px;">
#
# <strong style="color: #FFE0B2; font-size: 1.1em;">Analyse — Interpolation linéaire vs plus proche voisin :</strong>
# <br><br>
#
# **Améliorations observées :**
# - **Contours plus lisses** : suppression des artefacts en escalier (*staircase artifacts*)
# - **Bruit réduit** : atténuation des oscillations haute fréquence parasites
# - **Transitions naturelles** : meilleure continuité spatiale entre régions adjacentes
# - **Réduction de la pixellisation** : artefacts de discrétisation atténués
#
# **Coût computationnel :**
# Le surcoût est minime : l'interpolation linéaire nécessite une multiplication et une addition supplémentaire par voxel/projection, impactant le temps total de quelques pourcents seulement.
#
# **Conclusion :**
# L'interpolation linéaire est **recommandée** pour usage clinique : gain de qualité significatif pour un coût négligeable. Cette image devient notre **référence de qualité** pour les comparaisons suivantes.
#
# </div>

# %% [markdown]
# ## Reconstruction du sinogramme patient
#
# <div style="background-color: #1a1a2e; color: #a8d0e6; border-left: 5px solid #FF9800; padding: 12px 16px; border-radius: 5px; margin: 10px 0; font-size: 0.9em;">
# L'énoncé fournit deux sinogrammes : le sinogramme <em>password</em> (utilisé jusqu'ici pour valider les algorithmes) et le sinogramme <em>patient</em> (projections de type médical). On applique maintenant la méthode <strong>FBP avec interpolation linéaire (Q5)</strong> au sinogramme patient pour obtenir une image de qualité diagnostique.
# </div>

# %%
# Reconstruction du sinogramme patient (FBP + interpolation linéaire)
print("Reconstruction du sinogramme patient...")
sinogram_patient_filtered = filter_sinogram_ramp(sinogram_patient)
t_start = time.time()
image_patient = backproject_linear_interp(sinogram_patient_filtered, angles, nbvox, voxsize, pixsize)
t_end = time.time()
print(f"Temps de reconstruction patient : {t_end - t_start:.2f} s")

# Visualisation du patient reconstruit
fig, axes = plt.subplots(1, 2, figsize=(16, 7))

vmin1, vmax1 = np.percentile(image_fbp_linear, [1, 99])
im0 = axes[0].imshow(image_fbp_linear, cmap='gray', interpolation='nearest', vmin=vmin1, vmax=vmax1)
axes[0].set_title('FBP linéaire — Password (Q5)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('x (pixel)')
axes[0].set_ylabel('y (pixel)')
divider0 = make_axes_locatable(axes[0])
cax0 = divider0.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im0, cax=cax0, label=r'$\mu$ (cm$^{-1}$)')

vmin2, vmax2 = np.percentile(image_patient, [1, 99])
im1 = axes[1].imshow(image_patient, cmap='gray', interpolation='nearest', vmin=vmin2, vmax=vmax2)
axes[1].set_title('FBP linéaire — Patient', fontsize=14, fontweight='bold')
axes[1].set_xlabel('x (pixel)')
axes[1].set_ylabel('y (pixel)')
divider1 = make_axes_locatable(axes[1])
cax1 = divider1.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im1, cax=cax1, label=r'$\mu$ (cm$^{-1}$)')

fig.suptitle('Reconstruction FBP (interpolation linéaire) — Password vs Patient',
             fontsize=16, fontweight='bold', y=0.98)
plt.tight_layout()
plt.show()
# Out:
# Reconstruction du sinogramme patient...
#   Progression : 96/96 lignes (100%)
# Temps de reconstruction patient : 11.79 s

# %% [markdown]
# <div style="height: 50px;"></div>
# <div style="position: relative; margin: 30px 0;">
#     <div style="height: 3px; background: linear-gradient(90deg, transparent, #4CAF50, #2196F3, #4CAF50, transparent); border-radius: 3px;"></div>
#     <div style="position: absolute; top: 50%; left: 50%; transform: translate(-50%, -50%); background: #1e1e1e; padding: 0 20px;">
#         <span style="color: #4CAF50; font-size: 18px; font-weight: bold; letter-spacing: 3px;">✦ ✦ ✦</span>
#     </div>
# </div>
# <br />
#
# <a id="q6"></a>
#
# <div style="
#     background: linear-gradient(135deg, #0f0c29 0%, #302b63 100%);
#     padding: 22px 30px;
#     border-radius: 12px;
#     margin: 10px 0 20px 0;
#     box-shadow: 0 8px 25px rgba(15, 12, 41, 0.5);
#     border: 1px solid rgba(76, 175, 80, 0.3);
#     border-left: 5px solid #4CAF50;
# ">
#     <div style="display: flex; align-items: center; gap: 15px;">
#         <div style="
#             background: linear-gradient(135deg, #4CAF50, #2E7D32);
#             color: white;
#             width: 45px; height: 45px;
#             border-radius: 50%;
#             display: flex; align-items: center; justify-content: center;
#             font-size: 20px; font-weight: bold;
#             box-shadow: 0 4px 15px rgba(76, 175, 80, 0.4);
#             flex-shrink: 0;
#         ">6</div>
#         <h2 style="color: white; margin: 0; font-size: 22px; font-weight: 300; letter-spacing: 1px;">Reconstruction via le théorème de la tranche de Fourier</h2>
#     </div>
# </div>
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #4CAF50; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# **Énoncé :** *Écrivez une nouvelle fonction de reconstruction `reconFourierSlice()` qui effectue la reconstruction via le théorème de la tranche de Fourier. Il faut effectuer la TF 1D de chaque projection du sinogramme et stocker le nouveau sinogramme transformé. Par échantillonnage du sinogramme, remplissez l'espace de Fourier 2D de l'image à reconstruire. Vous pouvez choisir l'angle approprié par la méthode du plus proche voisin et la position sur le détecteur par interpolation linéaire. Trouvez l'image par $\mathrm{TF}^{-1}_{\mathrm{2D}}$.*
#
# </div>
#
# ### Rappel théorique — Fourier Slice Theorem
#
# La transformée de Fourier d'une projection 1D à un angle $\varphi$ correspond à une ligne de la TF 2D de l'image recherchée, au même angle :
#
# $$\mathcal{F}[p(t)]_{\varphi = \text{const}} = \mathrm{TF}_{2D}[\mu(t, \varphi = \text{const})]$$
#
# On peuple donc l'espace de Fourier $M(u, v)$ avec les lignes de projection $P(t)_\varphi$, puis on applique $\mathrm{TF}^{-1}_{2D}$ pour obtenir l'image.
#
# <div style="background-color: #1a1a2e; color: #a8d0e6; border-left: 5px solid #FFB300; padding: 12px; border-radius: 5px; margin-top: 10px; font-size: 0.9em;">
#
# 💡 **Indice :** Initialisez la matrice Fourier 2D en complexe : `mymatrix = numpy.zeros((a, b), 'complex')` afin d'éviter les changements de taille, puis prenez la partie réelle de l'image finale.
#
# </div>

# %%
def recon_fourier_slice(sinogram, angles, nbvox, voxsize, pixsize):
    """
    Reconstruction par théorème de la tranche de Fourier (Fourier Slice Theorem).

    Points critiques :
    1) Le sinogramme est centré (s=0 au centre du détecteur) -> ifftshift AVANT FFT 1D
    2) Mapping radial via fftfreq(..., d=pixsize) et fftfreq(..., d=voxsize)
    3) Recentrer l'image reconstruite -> fftshift après iFFT 2D
    """
    nbprj, nbpix = sinogram.shape

    # FFT des projections (centrage indispensable)
    SINOGRAM = fftshift(fft(ifftshift(sinogram, axes=1), axis=1), axes=1)

    # Axes de fréquences (cycles / cm)
    freq_detector = fftshift(fftfreq(nbpix, d=pixsize))
    freq_img      = fftshift(fftfreq(nbvox, d=voxsize))

    IMAGE_FOURIER = np.zeros((nbvox, nbvox), dtype=complex)

    # Remplissage du plan de Fourier (interpolation radiale + angle le plus proche)
    for v_idx, v in enumerate(freq_img):
        for u_idx, u in enumerate(freq_img):
            rho = np.sqrt(u*u + v*v)
            phi = np.arctan2(v, u)
            if phi < 0:
                phi += 2*np.pi

            # distance angulaire circulaire (0..pi)
            angle_diff = np.abs(((angles - phi + np.pi) % (2*np.pi)) - np.pi)
            angle_idx = int(np.argmin(angle_diff))

            # interpolation radiale sur la FFT 1D
            rho_idx = np.interp(rho, freq_detector, np.arange(nbpix), left=np.nan, right=np.nan)
            if np.isnan(rho_idx):
                continue

            i0 = int(np.floor(rho_idx))
            i1 = min(i0 + 1, nbpix - 1)
            frac = rho_idx - i0

            IMAGE_FOURIER[v_idx, u_idx] = (1 - frac) * SINOGRAM[angle_idx, i0] + frac * SINOGRAM[angle_idx, i1]

    # iFFT 2D + recentrage pour affichage
    image = fftshift(ifft2(ifftshift(IMAGE_FOURIER))).real
    return image

# Application de la reconstruction via Fourier Slice Theorem
print("Reconstruction via Fourier Slice Theorem...")
t_start = time.time()
image_fourier = recon_fourier_slice(sinogram_password, angles, nbvox, voxsize, pixsize)
t_end = time.time()
temps_fourier = t_end - t_start

print(f"Temps de reconstruction : {temps_fourier:.2f} secondes")
# Out:
# Reconstruction via Fourier Slice Theorem...
# Temps de reconstruction : 0.20 secondes

# %% [markdown]
# ## Observations préliminaires
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #4CAF50; padding: 15px; border-radius: 5px; margin-top: 10px;">
#
# <strong style="color: #C8E6C9; font-size: 1.05em;">Analyse du résultat FST (Q6-Q7) :</strong>
# <br><br>
#
# L'image reconstruite par **Fourier Slice Theorem** présente des artefacts visibles par rapport à la FBP linéaire (Q5). La comparaison visuelle ci-dessous met en évidence les différences.
#
# Les artefacts proviennent du **remplissage polaire** de l'espace de Fourier : la densité d'échantillonnage $\propto 1/\rho$ entraîne un **sous-échantillonnage en périphérie** (hautes fréquences), violant le critère de Nyquist-Shannon. ➜ Solution proposée en **Q8** : sur-échantillonnage 2×.
#
# </div>

# %%
# Visualisation
fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# Image reconstruite via Fourier Slice
vmin, vmax = np.percentile(image_fourier, [1, 99])
im0 = axes[0].imshow(image_fourier, cmap='gray', interpolation='nearest', vmin=vmin, vmax=vmax)
axes[0].set_title(f'Reconstruction — Fourier Slice Theorem\n(temps: {temps_fourier:.1f}s)', 
                  fontsize=14, fontweight='bold')
axes[0].set_xlabel('x (pixel)')
axes[0].set_ylabel('y (pixel)')
divider0 = make_axes_locatable(axes[0])
cax0 = divider0.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im0, cax=cax0, label=r'$\mu$ (cm$^{-1}$)')

# Comparaison avec FBP linéaire (Q5)
vmin2, vmax2 = np.percentile(image_fbp_linear, [1, 99])
im1 = axes[1].imshow(image_fbp_linear, cmap='gray', interpolation='nearest', vmin=vmin2, vmax=vmax2)
axes[1].set_title(f'Pour comparaison : FBP linéaire (Q5)\n(temps: {temps_fbp_linear:.1f}s)', 
                  fontsize=14, fontweight='bold')
axes[1].set_xlabel('x (pixel)')
axes[1].set_ylabel('y (pixel)')
divider1 = make_axes_locatable(axes[1])
cax1 = divider1.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im1, cax=cax1, label=r'$\mu$ (cm$^{-1}$)')

fig.suptitle('Reconstruction via théorème de la tranche de Fourier', 
             fontsize=16, fontweight='bold', y=0.98)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #252526; color: white; border-left: 5px solid #FF5733; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# <strong style="color: #FFCCBC; font-size: 1.1em;">Analyse du résultat FST :</strong>
# <br><br>
#
# **Artefacts observés :**
# - **Motif en grille** : structure géométrique due à l'interpolation polaire → cartésienne
# - **Aliasing** : sous-échantillonnage en périphérie de l'espace de Fourier ($\rho \to \rho_{\max}$)
# - **Contours dégradés** : transitions moins nettes qu'en FBP
# - **Contraste réduit** : dynamique d'intensité comprimée
#
# **Comparaison avec FBP (Q5) :**
#
# **Tableau 7 : Comparaison FST vs FBP linéaire**
#
# | Critère | FST (Q6) | FBP linéaire (Q5) |
# |:--------|:---------|:------------------|
# | Netteté | Artefacts grille | Nette |
# | Contraste | Réduit | Bon |
# | Vitesse | Rapide (FFT) | Lente (triple boucle) |
# | Qualité globale | Inférieure | Supérieure |
#
# **Solution :** Sur-échantillonner l'espace de Fourier sur une grille 2× plus dense (Q8) pour mieux respecter Nyquist.
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div>
# <div style="position: relative; margin: 30px 0;">
#     <div style="height: 3px; background: linear-gradient(90deg, transparent, #F44336, #FF9800, #F44336, transparent); border-radius: 3px;"></div>
#     <div style="position: absolute; top: 50%; left: 50%; transform: translate(-50%, -50%); background: #1e1e1e; padding: 0 20px;">
#         <span style="color: #F44336; font-size: 18px; font-weight: bold; letter-spacing: 3px;">✦ ✦ ✦</span>
#     </div>
# </div>
# <br />
#
# <a id="q7"></a>
#
# <div style="
#     background: linear-gradient(135deg, #0f0c29 0%, #302b63 100%);
#     padding: 22px 30px;
#     border-radius: 12px;
#     margin: 10px 0 20px 0;
#     box-shadow: 0 8px 25px rgba(15, 12, 41, 0.5);
#     border: 1px solid rgba(244, 67, 54, 0.3);
#     border-left: 5px solid #F44336;
# ">
#     <div style="display: flex; align-items: center; gap: 15px;">
#         <div style="
#             background: linear-gradient(135deg, #F44336, #C62828);
#             color: white;
#             width: 45px; height: 45px;
#             border-radius: 50%;
#             display: flex; align-items: center; justify-content: center;
#             font-size: 20px; font-weight: bold;
#             box-shadow: 0 4px 15px rgba(244, 67, 54, 0.4);
#             flex-shrink: 0;
#         ">7</div>
#         <h2 style="color: white; margin: 0; font-size: 22px; font-weight: 300; letter-spacing: 1px;">Résultat de la reconstruction TF 2D</h2>
#     </div>
# </div>
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #F44336; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# **Énoncé :** *Incluez dans le rapport et décrivez brièvement le résultat obtenu. Il est fort probable que l'image soit loin de vos attentes, même si le code est correct. Notez également le temps de reconstruction.*
#
# </div>

# %%
# Visualisation comparative complète
fig = plt.figure(figsize=(18, 12))
gs = fig.add_gridspec(3, 3, hspace=0.3, wspace=0.3)

# Ligne 1 : Comparaison des 3 méthodes
ax1 = fig.add_subplot(gs[0, 0])
vmin1, vmax1 = np.percentile(image_lam, [1, 99])
im1 = ax1.imshow(image_lam, cmap='gray', interpolation='nearest', vmin=vmin1, vmax=vmax1)
ax1.set_title('Laminogramme (Q2)', fontsize=12, fontweight='bold')
plt.colorbar(im1, ax=ax1, fraction=0.046, label=r'$\mu$ (cm$^{-1}$)')

ax2 = fig.add_subplot(gs[0, 1])
vmin2, vmax2 = np.percentile(image_fbp_linear, [1, 99])
im2 = ax2.imshow(image_fbp_linear, cmap='gray', interpolation='nearest', vmin=vmin2, vmax=vmax2)
ax2.set_title('FBP avec interp. linéaire (Q5)', fontsize=12, fontweight='bold')
plt.colorbar(im2, ax=ax2, fraction=0.046, label=r'$\mu$ (cm$^{-1}$)')

ax3 = fig.add_subplot(gs[0, 2])
vmin3, vmax3 = np.percentile(image_fourier, [1, 99])
im3 = ax3.imshow(image_fourier, cmap='gray', interpolation='nearest', vmin=vmin3, vmax=vmax3)
ax3.set_title('Fourier Slice (Q6)', fontsize=12, fontweight='bold')
plt.colorbar(im3, ax=ax3, fraction=0.046, label=r'$\mu$ (cm$^{-1}$)')

# Ligne 2 : Zoom sur région centrale
roi_size = 30
center = nbvox // 2
roi_slice = (slice(center - roi_size//2, center + roi_size//2),
             slice(center - roi_size//2, center + roi_size//2))

ax4 = fig.add_subplot(gs[1, 0])
ax4.imshow(image_lam[roi_slice], cmap='gray', interpolation='nearest')
ax4.set_title('ROI — Laminogramme', fontsize=11)

ax5 = fig.add_subplot(gs[1, 1])
ax5.imshow(image_fbp_linear[roi_slice], cmap='gray', interpolation='nearest')
ax5.set_title('ROI — FBP', fontsize=11)

ax6 = fig.add_subplot(gs[1, 2])
ax6.imshow(image_fourier[roi_slice], cmap='gray', interpolation='nearest')
ax6.set_title('ROI — Fourier Slice', fontsize=11)

# Ligne 3 : Profils horizontaux au centre
ax7 = fig.add_subplot(gs[2, :])
profile_lam = image_lam[center, :]
profile_fbp = image_fbp_linear[center, :]
profile_fourier = image_fourier[center, :]

ax7.plot(profile_lam, 'b-', linewidth=2, alpha=0.7, label='Laminogramme')
ax7.plot(profile_fbp, 'g-', linewidth=2, alpha=0.7, label='FBP')
ax7.plot(profile_fourier, 'r-', linewidth=2, alpha=0.7, label='Fourier Slice')
ax7.set_title('Profil horizontal au centre de l\'image', fontsize=12, fontweight='bold')
ax7.set_xlabel('Position x (pixel)')
ax7.set_ylabel('Intensité')
ax7.grid(alpha=0.3)
ax7.legend(fontsize=11)

fig.suptitle('Analyse comparative des méthodes de reconstruction', 
             fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# ## Analyse détaillée — Laminogramme vs FBP vs Fourier Slice
#
# ### Observations qualitatives
#
# **Ligne 1 — Comparaison globale :**
# - **Laminogramme (Q2)** : flou extrême, motif en étoile, inutilisable cliniquement
# - **FBP linéaire (Q5)** : nette, contours bien définis, qualité diagnostique
# - **Fourier Slice (Q6)** : artefacts en grille, qualité inférieure à FBP
#
# **Ligne 2 — Zoom ROI :**
# - Motif géométrique visible en Fourier Slice (structure en damier)
# - FBP conserve la résolution des structures fines
#
# **Ligne 3 — Profils d'intensité :**
# - Laminogramme : variations lentes et douces (flou)
# - FBP : transitions nettes et précises
# - Fourier Slice : oscillations parasites, transitions moins définies
#
# ### Origine des artefacts FST
#
# Le problème provient de l'échantillonnage en **coordonnées polaires** de l'espace de Fourier :
#
# $$\text{Densité spatiale} \propto \frac{1}{\rho}$$
#
# En périphérie ($\rho \to \rho_{\max}$), la densité est trop faible → **violation du critère de Nyquist-Shannon**. La conversion polaire → cartésienne crée des **lacunes** dans la grille $(u, v)$, générant le motif géométrique visible.
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #FF5733; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# <strong style="color: #FFCCBC; font-size: 1.1em;">Bilan comparatif :</strong>
# <br><br>
#
# **Tableau 8 : Acceptabilité clinique des méthodes**
#
# | Méthode | Qualité | Acceptabilité clinique |
# |:--------|:--------|:-----------------------|
# | Laminogramme (Q2) | Très faible | Non |
# | FBP linéaire (Q5) | Excellente | **Oui** |
# | Fourier Slice (Q6) | Moyenne | Non |
#
# **Verdict :** FBP est plus rapide et de meilleure qualité. La reconstruction FST nécessite un **sur-échantillonnage** (Q8) pour devenir exploitable.
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div>
# <div style="position: relative; margin: 30px 0;">
#     <div style="height: 3px; background: linear-gradient(90deg, transparent, #3F51B5, #00BCD4, #3F51B5, transparent); border-radius: 3px;"></div>
#     <div style="position: absolute; top: 50%; left: 50%; transform: translate(-50%, -50%); background: #1e1e1e; padding: 0 20px;">
#         <span style="color: #3F51B5; font-size: 18px; font-weight: bold; letter-spacing: 3px;">✦ ✦ ✦</span>
#     </div>
# </div>
# <br />
#
# <a id="q8"></a>
#
# <div style="
#     background: linear-gradient(135deg, #0f0c29 0%, #302b63 100%);
#     padding: 22px 30px;
#     border-radius: 12px;
#     margin: 10px 0 20px 0;
#     box-shadow: 0 8px 25px rgba(15, 12, 41, 0.5);
#     border: 1px solid rgba(63, 81, 181, 0.3);
#     border-left: 5px solid #3F51B5;
# ">
#     <div style="display: flex; align-items: center; gap: 15px;">
#         <div style="
#             background: linear-gradient(135deg, #3F51B5, #283593);
#             color: white;
#             width: 45px; height: 45px;
#             border-radius: 50%;
#             display: flex; align-items: center; justify-content: center;
#             font-size: 20px; font-weight: bold;
#             box-shadow: 0 4px 15px rgba(63, 81, 181, 0.4);
#             flex-shrink: 0;
#         ">8</div>
#         <h2 style="color: white; margin: 0; font-size: 22px; font-weight: 300; letter-spacing: 1px;">Sur-échantillonnage — Grille 2× plus dense</h2>
#     </div>
# </div>
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #3F51B5; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# **Énoncé :** *Tentez de reconstruire l'image en soumettant une grille d'image deux fois plus dense dans chaque direction (doubler le nombre de voxels et réduire leur taille deux fois dans le fichier `geometry.py`). Quelles améliorations observez-vous ? L'image est-elle acceptable pour un diagnostic médical ? Basez votre discussion sur la définition-même de la TF et sur le théorème de Nyquist-Shannon.*
#
# </div>
#
# <div style="background-color: #1a1a2e; color: #a8d0e6; border-left: 5px solid #FFB300; padding: 12px; border-radius: 5px; margin-top: 10px; font-size: 0.9em;">
#
# 💡 **Théorème de Nyquist-Shannon :** Un signal doit être échantillonné à au moins deux fois sa fréquence maximale pour éviter le repliement spectral (*aliasing*). La grille 2× plus dense permet d'explorer cette limite.
#
# </div>

# %%
# Q8 — Grille 2× plus dense, conformément aux options prévues dans geometry.py :

# Paramètres Q8 (2× plus dense)
nbvox_2x   = 192
voxsize_2x = 0.2

print(f"Configuration Q6 (geometry.py defaults) : {nbvox}×{nbvox} voxels, taille {voxsize} cm")
print(f"Configuration Q8 (geometry.py modifié)  : {nbvox_2x}×{nbvox_2x} voxels, taille {voxsize_2x} cm")

t_start = time.time()
image_fourier_2x = recon_fourier_slice(sinogram_password, angles, nbvox_2x, voxsize_2x, pixsize)
t_end = time.time()
temps_fourier_2x = t_end - t_start
temps_fourier_2x_q8 = temps_fourier_2x  # Sauvegarde pour Q9

print(f"Temps reconstruction : {temps_fourier_2x:.2f}s  (Q6: {temps_fourier:.2f}s, ratio: {temps_fourier_2x/temps_fourier:.2f}×)")
# Out:
# Configuration Q6 (geometry.py defaults) : 96×96 voxels, taille 0.4 cm
# Configuration Q8 (geometry.py modifié)  : 192×192 voxels, taille 0.2 cm
# Temps reconstruction : 0.73s  (Q6: 0.20s, ratio: 3.71×)

# %% [markdown]
# <div style="background-color: #252526; color: white; border-left: 5px solid #3F51B5; padding: 15px; border-radius: 5px; margin-top: 20px;">
#
# <strong style="color: #C5CAE9; font-size: 1.1em;">Analyse des améliorations — Sur-échantillonnage 2× :</strong>
# <br><br>
#
# **Qualité d'image observée :**
#
# *Améliorations significatives :*
# - Réduction des artefacts en grille (grid artifacts)
# - Contours plus nets et mieux définis
# - Structures fines mieux résolues
# - Moins d'aliasing (repliement spectral)
# - Meilleure continuité spatiale
#
# *Limitations persistantes :*
# - Qualité encore inférieure à FBP (interpolation linéaire Q5)
# - Contraste légèrement dégradé
# - Artefacts résiduels présents (moins visibles)
#
# **Explication théorique — Critère de Nyquist :**
#
# Avec la grille **96×96 (Q6)**, la fréquence d'échantillonnage est insuffisante en périphérie → repliement spectral (*aliasing*) → artefacts visibles. Avec la grille **192×192 (Q8)**, la fréquence d'échantillonnage est doublée → critère de Nyquist mieux respecté → capture des hautes fréquences spatiales.
#
# Par définition de la TF discrète, la fréquence maximale représentable sur une grille de pas $\Delta{x}$ est $f_{max}⁡ = 1/(2 \Delta{x})$. Avec $\Delta{x} = 0.4$ cm (Q6), $f_{max} = 1.25$ cycles/cm, tandis que le détecteur échantillonne jusqu'à $1/(2 \times 0.165) \approx 3.03$ cycles/cm. La grille Q6 ne peut donc pas représenter tout le contenu spectral du sinogramme, causant du repliement. La grille Q8 $(\Delta{x} = 0.2$ cm, $f_{max} = 2.5$ cycles/cm) couvre une plus grande portion du spectre.
#
# **Verdict diagnostic :** Image acceptable pour certaines applications, mais pas optimale. FBP reste le standard pour qualité clinique.
#
# </div>

# %%
# Visualisation comparative
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# Grille originale 96×96
vmin1, vmax1 = np.percentile(image_fourier, [1, 99])
im0 = axes[0].imshow(image_fourier, cmap='gray', interpolation='nearest', vmin=vmin1, vmax=vmax1)
axes[0].set_title(f'Fourier Slice — Grille {nbvox}×{nbvox}\n(Q6, temps: {temps_fourier:.1f}s)', 
                  fontsize=13, fontweight='bold')
axes[0].set_xlabel('x (pixel)')
axes[0].set_ylabel('y (pixel)')
divider0 = make_axes_locatable(axes[0])
cax0 = divider0.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im0, cax=cax0, label=r'$\mu$ (cm$^{-1}$)')

# Grille sur-échantillonnée 192×192
vmin2, vmax2 = np.percentile(image_fourier_2x, [1, 99])
im1 = axes[1].imshow(image_fourier_2x, cmap='gray', interpolation='nearest', vmin=vmin2, vmax=vmax2)
axes[1].set_title(f'Fourier Slice — Grille {nbvox_2x}×{nbvox_2x}\n(Q8, temps: {temps_fourier_2x:.1f}s)', 
                  fontsize=13, fontweight='bold', color='darkgreen')
axes[1].set_xlabel('x (pixel)')
axes[1].set_ylabel('y (pixel)')
divider1 = make_axes_locatable(axes[1])
cax1 = divider1.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im1, cax=cax1, label=r'$\mu$ (cm$^{-1}$)')

# FBP pour référence
im2 = axes[2].imshow(image_fbp_linear, cmap='gray', interpolation='nearest', vmin=vmin2, vmax=vmax2)
axes[2].set_title(f'FBP linéaire (référence, Q5)\ntemps: {temps_fbp_linear:.1f}s', 
                  fontsize=13, fontweight='bold')
axes[2].set_xlabel('x (pixel)')
axes[2].set_ylabel('y (pixel)')
divider2 = make_axes_locatable(axes[2])
cax2 = divider2.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im2, cax=cax2, label=r'$\mu$ (cm$^{-1}$)')

fig.suptitle('Impact du sur-échantillonnage sur la reconstruction Fourier Slice', 
             fontsize=16, fontweight='bold', y=0.98)
plt.tight_layout()
plt.show()

# Zoom comparatif
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

roi_size_1x = 30
center_1x = nbvox // 2
roi_1x = (slice(center_1x - roi_size_1x//2, center_1x + roi_size_1x//2),
          slice(center_1x - roi_size_1x//2, center_1x + roi_size_1x//2))

roi_size_2x = 60  # 2× plus grand
center_2x = nbvox_2x // 2
roi_2x = (slice(center_2x - roi_size_2x//2, center_2x + roi_size_2x//2),
          slice(center_2x - roi_size_2x//2, center_2x + roi_size_2x//2))

axes[0].imshow(image_fourier[roi_1x], cmap='gray', interpolation='nearest')
axes[0].set_title(f'ROI — Grille {nbvox}×{nbvox}', fontsize=13, fontweight='bold')

axes[1].imshow(image_fourier_2x[roi_2x], cmap='gray', interpolation='nearest')
axes[1].set_title(f'ROI — Grille {nbvox_2x}×{nbvox_2x}', fontsize=13, fontweight='bold', color='darkgreen')

fbp_upsampled = zoom(image_fbp_linear, 2, order=1)
roi_fbp = (slice(center_2x - roi_size_2x//2, center_2x + roi_size_2x//2),
           slice(center_2x - roi_size_2x//2, center_2x + roi_size_2x//2))
axes[2].imshow(fbp_upsampled[roi_fbp], cmap='gray', interpolation='nearest')
axes[2].set_title('ROI — FBP (upsampled)', fontsize=13, fontweight='bold')

fig.suptitle('Zoom ROI — Même région spatiale couverte', fontsize=15, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Configuration de sur-échantillonnage
#
# Le sur-échantillonnage consiste à doubler la résolution de la grille de reconstruction tout en conservant la même couverture spatiale :
#
# **Tableau 9 : Paramètres de sur-échantillonnage**
#
# | Paramètre | Q6 (original) | Q8 (2×) | Observation |
# |:----------|:-------------|:--------|:------------|
# | Nombre de voxels | 96 × 96 | **192 × 192** | ×4 voxels au total |
# | Taille voxel | 0.4 cm | **0.2 cm** | ÷2 taille |
# | Couverture spatiale | 38.4 cm | 38.4 cm | *Identique* |
# | **Fréquence d'échantillonnage** | $f_s$ | **$2f_s$** | **×2** |
#
# <div style="background-color: #1a1a2e; color: #a8d0e6; border-left: 5px solid #FFB300; padding: 12px 16px; border-radius: 5px; margin: 10px 0; font-size: 0.9em;">
#
# <strong>Théorème de Nyquist-Shannon :</strong> Pour éviter le <strong>repliement spectral</strong> (aliasing), il faut respecter $f_{\text{échantillonnage}} \geq 2 \times f_{\text{max}}$.
#
# Avec la grille 96×96, l'échantillonnage était <strong>insuffisant</strong> en périphérie de l'espace de Fourier, créant des artefacts de repliement. La grille 192×192 double la fréquence d'échantillonnage, <strong>réduisant l'aliasing</strong>.
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div>
# <div style="position: relative; margin: 30px 0;">
#     <div style="height: 3px; background: linear-gradient(90deg, transparent, #3F51B5, #00BCD4, #3F51B5, transparent); border-radius: 3px;"></div>
#     <div style="position: absolute; top: 50%; left: 50%; transform: translate(-50%, -50%); background: #1e1e1e; padding: 0 20px;">
#         <span style="color: #3F51B5; font-size: 18px; font-weight: bold; letter-spacing: 3px;">✦ ✦ ✦</span>
#     </div>
# </div>
# <br />
#
# <a id="q9"></a>
#
# <div style="
#     background: linear-gradient(135deg, #0f0c29 0%, #302b63 100%);
#     padding: 22px 30px;
#     border-radius: 12px;
#     margin: 10px 0 20px 0;
#     box-shadow: 0 8px 25px rgba(15, 12, 41, 0.5);
#     border: 1px solid rgba(63, 81, 181, 0.3);
#     border-left: 5px solid #3F51B5;
# ">
#     <div style="display: flex; align-items: center; gap: 15px;">
#         <div style="
#             background: linear-gradient(135deg, #3F51B5, #283593);
#             color: white;
#             width: 45px; height: 45px;
#             border-radius: 50%;
#             display: flex; align-items: center; justify-content: center;
#             font-size: 20px; font-weight: bold;
#             box-shadow: 0 4px 15px rgba(63, 81, 181, 0.4);
#             flex-shrink: 0;
#         ">9</div>
#         <h2 style="color: white; margin: 0; font-size: 22px; font-weight: 300; letter-spacing: 1px;">Comparaison des performances — Temps de reconstruction et boucles</h2>
#     </div>
# </div>
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #3F51B5; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# **Énoncé :** *Comparez les temps de reconstruction de la rétroprojection filtrée, la reconstruction TF₂D et cette dernière avec sur-échantillonnage. Discutez de la taille des boucles `for` imbriquées dans ces trois cas et/ou de l'utilité du slicing si applicable.*
#
# </div>
#
# <div style="background-color: #1a1a2e; color: #a8d0e6; border-left: 5px solid #FFB300; padding: 12px; border-radius: 5px; margin-top: 10px; font-size: 0.9em;">
#
# **Méthodes à comparer (selon l'énoncé) :**
# 1. **Rétroprojection filtrée (FBP)** — Q5, avec interpolation linéaire (`get_proj_value_linear`)
# 2. **Reconstruction TF₂D** — Q6, grille 96×96
# 3. **TF₂D avec sur-échantillonnage** — Q8, grille 192×192
#
# Les méthodes Q2 (laminogramme) et Q4 (FBP sans interpolation) sont également incluses dans le graphique comparatif pour une vue complète.
#
# </div>

# %%
# Rassembler tous les temps mesurés
methodes = [
    "Laminogramme (Q2)",
    "FBP + ramp filter (Q4)",
    "FBP + interpolation linéaire (Q5)",
    "Fourier Slice 96x96 (Q6)",
    "Fourier Slice 192x192 (Q8)"
]

temps_mesures = [
    temps_lam,         # Q2
    temps_fbp,         # Q4
    temps_fbp_linear,  # Q5
    temps_fourier,     # Q6
    temps_fourier_2x_q8    # Q8
]

temps_ref = temps_fbp_linear  # Référence

# Tableau comparatif
print(f"{'Méthode':<40} {'Temps (s)':<15} {'Relatif':<12} {'Qualité'}")
print("-" * 85)

qualites = ["*", "***", "***** (réf.)", "**", "****"]

for methode, temps, qualite in zip(methodes, temps_mesures, qualites):
    relatif = temps / temps_ref
    print(f"{methode:<40} {temps:<15.2f} {relatif:<12.2f}x {qualite}")

print("-" * 85)
print(f"{'RÉFÉRENCE : FBP interpolation linéaire':<40} {temps_ref:<15.2f} {'1.00x':<12}")
# Out:
# Méthode                                  Temps (s)       Relatif      Qualité
# -------------------------------------------------------------------------------------
# Laminogramme (Q2)                        15.71           1.35        x *
# FBP + ramp filter (Q4)                   16.81           1.44        x ***
# FBP + interpolation linéaire (Q5)        11.64           1.00        x ***** (réf.)
# Fourier Slice 96x96 (Q6)                 0.20            0.02        x **
# Fourier Slice 192x192 (Q8)               0.73            0.06        x ****
# -------------------------------------------------------------------------------------
# RÉFÉRENCE : FBP interpolation linéaire   11.64           1.00x

# %% [markdown]
# ### Conclusions et recommandations
#
# Le diagramme **temps-qualité** permet de visualiser le compromis entre performance et qualité d'image.
#
# **Tableau 10 : Recommandations par cas d'usage**
#
# | Contexte | Méthode recommandée | Justification |
# |:---------|:-------------------|:--------------|
# | **Diagnostic clinique standard** | FBP + interpolation linéaire (Q5) | Meilleur compromis qualité/temps |
# | **Imagerie temps réel (urgence)** | Fourier Slice 96×96 (Q6) | Le plus rapide, qualité acceptable |
# | **Recherche / Haute qualité** | FBP + interpolation linéaire (Q5) | Qualité optimale |
# | **Démonstration pédagogique** | Fourier Slice 192×192 (Q8) | Illustre le théorème de Fourier |
# | **Jamais** | Laminogramme (Q2) | Trop lent, qualité insuffisante |
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #3F51B5; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# <strong style="color: #C5CAE9; font-size: 1.05em;">Verdict final :</strong>
# <br><br>
#
# **Par qualité (décroissant) :** FBP linéaire (Q5) → Fourier 192×192 (Q8) → FBP ramp (Q4) → Fourier 96×96 (Q6) → Laminogramme (Q2)
#
# **Par vitesse (croissant) :** Fourier 96×96 < Fourier 192×192 ≈ FBP linéaire ≈ FBP ramp ≪ Laminogramme
#
# **FBP + interpolation linéaire (Q5)** est le **gold standard** — algorithme robuste, éprouvé cliniquement, excellent compromis qualité/temps. Le sur-échantillonnage (Q8) démontre l'importance du **critère de Nyquist-Shannon**.
#
# </div>

# %%
# Visualisations graphiques
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

# Graphique 1 : Temps absolus
colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A', '#98D8C8']
bars1 = ax1.bar(range(len(methodes)), temps_mesures, color=colors, edgecolor='black', linewidth=1.5)
ax1.set_xticks(range(len(methodes)))
ax1.set_xticklabels([m.replace(" ", "\n") for m in methodes], fontsize=10, ha='center')
ax1.set_ylabel('Temps de calcul (secondes)', fontsize=12, fontweight='bold')
ax1.set_title('Temps de calcul absolus', fontsize=14, fontweight='bold')
ax1.grid(axis='y', linestyle='--', alpha=0.7)

for bar, temps in zip(bars1, temps_mesures):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height,
             f'{temps:.2f}s', ha='center', va='bottom', fontsize=10, fontweight='bold')

# Graphique 2 : Temps relatifs (log scale)
temps_relatifs = [t / temps_ref for t in temps_mesures]
bars2 = ax2.bar(range(len(methodes)), temps_relatifs, color=colors, edgecolor='black', linewidth=1.5)
ax2.set_xticks(range(len(methodes)))
ax2.set_xticklabels([m.replace(" ", "\n") for m in methodes], fontsize=10, ha='center')
ax2.set_ylabel('Temps relatif (FBP interp. linéaire = 1)', fontsize=12, fontweight='bold')
ax2.set_title('Temps relatifs (échelle log)', fontsize=14, fontweight='bold')
ax2.set_yscale('log')
ax2.axhline(y=1.0, color='red', linestyle='--', linewidth=2, label='Référence (1×)')
ax2.grid(axis='y', linestyle='--', alpha=0.7, which='both')
ax2.legend()

for bar, rel in zip(bars2, temps_relatifs):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height,
             f'{rel:.2f}×', ha='center', va='bottom', fontsize=10, fontweight='bold')

fig.suptitle('Comparaison des performances temporelles', fontsize=16, fontweight='bold', y=0.98)
plt.tight_layout()
plt.show()

# Diagramme temps-qualité
fig, ax = plt.subplots(figsize=(12, 8))

qualite_scores = [1, 6, 10, 4, 8]  # Scores qualitatifs

scatter = ax.scatter(temps_mesures, qualite_scores, s=500, c=colors, edgecolor='black', linewidth=2, alpha=0.8)

for i, (methode, temps, qual) in enumerate(zip(methodes, temps_mesures, qualite_scores)):
    ax.annotate(methode.replace(" + ", "+\n"), xy=(temps, qual), xytext=(10, 10),
                textcoords='offset points', fontsize=10, fontweight='bold',
                bbox=dict(boxstyle='round,pad=0.5', facecolor=colors[i], alpha=0.6))

ax.set_xlabel('Temps de calcul (secondes)', fontsize=13, fontweight='bold')
ax.set_ylabel('Qualité d\'image (score qualitatif)', fontsize=13, fontweight='bold')
ax.set_title('Diagramme temps-qualité — Trade-off des méthodes de reconstruction', fontsize=15, fontweight='bold')
ax.grid(True, linestyle='--', alpha=0.6)
ax.set_xlim(left=0)
ax.set_ylim(0, 11)

# Zones
ax.axhspan(7, 11, xmax=0.3, alpha=0.2, color='green', label='Zone optimale (rapide + qualité)')
ax.axhspan(0, 4, alpha=0.2, color='red', label='Zone inadaptée (lent ou mauvaise qualité)')
ax.legend(loc='lower right', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analyse des boucles `for` imbriquées — Les 3 méthodes de l'énoncé
#
# L'énoncé demande explicitement d'analyser les **3 méthodes** : rétroprojection filtrée (FBP), reconstruction TF₂D (Q6) et TF₂D avec sur-échantillonnage (Q8).
#
# **Tableau 11 : Boucles `for` imbriquées et complexité**
#
# | Méthode (Q#) | Boucles imbriquées | Itérations totales | Complexité |
# |:------------|:-------------------|:-------------------|:-----------|
# | **FBP linéaire (Q5)** | 3 : `j` × `i` × `angles` | $N_{\text{vox}}^2 \times N_{\text{proj}}$ = $96^2 \times 720 \approx 6{,}6 \times 10^6$ | $\mathcal{O}(N_{\text{vox}}^2 \cdot N_{\text{proj}})$ |
# | **FST 96×96 (Q6)** | 2 : `v_idx` × `u_idx` (+ interp vectorisée) | $N_{\text{vox}}^2$ = $96^2 = 9{,}2 \times 10^3$ pixels à remplir | $\mathcal{O}(N_{\text{proj}} \cdot N_{\text{pix}} + N_{\text{vox}}^2)$ |
# | **FST 192×192 (Q8)** | Idem, mais $N_{\text{vox}} = 192$ | $192^2 = 36{,}9 \times 10^3$ pixels | $\mathcal{O}(N_{\text{proj}} \cdot N_{\text{pix}} + 4 N_{\text{vox}}^2)$ |
#
# #### Détail par méthode
#
# **Rétroprojection filtrée — FBP (Q4-Q5)**
#
# ```
# for j in range(96):           # N_vox = 96 itérations (lignes image)
#   for i in range(96):         # N_vox = 96 itérations (colonnes image)
#     for a_idx, phi in angles: # N_proj = 720 itérations (projections)
#         t_pixel = ...
#         val += geo.get_proj_value_linear(sino[a_idx], t_pixel)
# ```
# → **3 boucles imbriquées** : $96 \times 96 \times 720 \approx 6{,}6 \times 10^6$ appels. Le filtre rampe (étape préalable) est vectorisé via `numpy.fft` (pas de boucle Python explicite, $\mathcal{O}(N_{\text{proj}} \times N_{\text{pix}} \log N_{\text{pix}})$).
#
# **Fourier Slice Theorem — FST 96×96 (Q6)**
#
# ```
# # Étape 1 : FFT 1D vectorisée sur toutes les projections (slicing numpy)
# SINOGRAM = fftshift(fft(ifftshift(sinogram, axes=1), axis=1), axes=1)
#
# # Étape 2 : remplissage du plan de Fourier
# for v_idx in range(96):       # N_vox = 96
#   for u_idx in range(96):     # N_vox = 96
#       rho, phi = ...
#       angle_idx = argmin(...)  # O(N_proj) — vecteur de 720 éléments
#       IMAGE_FOURIER[v_idx, u_idx] = interp(...)
# ```
# → **2 boucles Python** + `argmin` $\mathcal{O}(N_{\text{proj}})$ interne = coût réel $96^2 \times N_{\text{proj}}$. L'étape 1 (FFT) est **entièrement vectorisée** par slicing numpy et ne génère pas de boucle Python.
#
# **Fourier Slice Theorem — FST 192×192 (Q8)**
#
# Même structure que Q6, mais $N_{\text{vox}} = 192$ :
# → $192^2 = 4 \times 96^2$ → **temps ×4** par rapport à Q6, ce qu'on observe expérimentalement.
#
# #### Utilité du slicing
#
# - **FFT du sinogramme** (Q3, Q6, Q8) : `fft(sinogram, axis=1)` traite toutes les projections **simultanément** — slicing numpy qui évite une boucle Python de $N_{\text{proj}} = 720$ itérations → gain majeur.
# - **Rétroprojection** (Q2, Q4, Q5) : la boucle interne sur les angles pourrait également être vectorisée par slicing (`t_pixels = x_vox @ cos_phi + y_vox @ sin_phi`), ce qui éliminerait la 3e boucle et réduirait le temps d'un facteur ~$N_{\text{proj}}$.
#
# <div style="background-color: #252526; color: white; border-left: 5px solid #3F51B5; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# <strong style="color: #C5CAE9; font-size: 1.05em;">Conclusion — Compromis temps / qualité :</strong>
# <br><br>
#
# | Méthode | Temps (s) | Qualité | Boucles Python |
# |:--------|:---------:|:-------:|:--------------:|
# | FBP + interp. linéaire (Q5) | ~référence | ★★★★★ | 3 |
# | FST 96×96 (Q6) | ~rapide | ★★☆☆☆ | 2 (+argmin) |
# | FST 192×192 (Q8) | ~4× Q6 | ★★★☆☆ | 2 (+argmin) |
#
# **FBP reste le standard clinique** malgré 3 boucles, car chaque itération est très legère (accès mémoire direct + `get_proj_value_linear`). Le FST gagne en vitesse sur l'étape FFT (vectorisée), mais perd sur le remplissage 2D avec `argmin`. Une implémentation optimisée du FST pré-calculerait les indices d'angle et vectoriserait le remplissage pour dépasser la FBP.
#
# </div>

# %% [markdown]
# <div style="height: 50px;"></div>
# <div style="position: relative; margin: 30px 0;">
#     <div style="height: 3px; background: linear-gradient(90deg, transparent, #4CAF50, #8BC34A, #4CAF50, transparent); border-radius: 3px;"></div>
#     <div style="position: absolute; top: 50%; left: 50%; transform: translate(-50%, -50%); background: #1e1e1e; padding: 0 20px;">
#         <span style="color: #4CAF50; font-size: 18px; font-weight: bold; letter-spacing: 3px;">✦ ✦ ✦</span>
#     </div>
# </div>
# <br />
#
# <a id="q10"></a>
#
# <div style="
#     background: linear-gradient(135deg, #1b5e20 0%, #2e7d32 100%);
#     padding: 22px 30px;
#     border-radius: 12px;
#     margin: 10px 0 20px 0;
#     box-shadow: 0 8px 25px rgba(27, 94, 32, 0.5);
#     border: 1px solid rgba(76, 175, 80, 0.3);
#     border-left: 5px solid #4CAF50;
# ">
#     <div style="display: flex; align-items: center; gap: 15px;">
#         <div style="
#             background: linear-gradient(135deg, #4CAF50, #388E3C);
#             color: white;
#             width: 45px; height: 45px;
#             border-radius: 50%;
#             display: flex; align-items: center; justify-content: center;
#             font-size: 16px; font-weight: bold;
#             box-shadow: 0 4px 15px rgba(76, 175, 80, 0.4);
#             flex-shrink: 0;
#         ">10</div>
#         <h2 style="color: white; margin: 0; font-size: 22px; font-weight: 300; letter-spacing: 1px;">BONUS — Interpolation avec lissage angulaire et interpolation linéaire radiale</h2>
#     </div>
# </div>
#
# <div style="background-color: #1b5e20; color: white; border-left: 5px solid #4CAF50; padding: 15px; border-radius: 5px; margin-top: 15px;">
#
# **Énoncé :** *Pour améliorer encore : interpolation bilinéaire (Q10 BONUS).*
#
# </div>
#
# <div style="background-color: #1a2e1a; color: #a8d0c6; border-left: 5px solid #FFB300; padding: 12px; border-radius: 5px; margin-top: 10px; font-size: 0.9em;">
#
# 💡 **Approche implémentée :** Au lieu d'utiliser seulement le plus proche voisin en angle (Q6), on effectue un **lissage angulaire** en combinant les projections voisines (±1 angle) pondérées par la proximité angulaire, combiné à une **interpolation linéaire** sur les fréquences radiales. Cette approche interpole les valeurs Fourier en utilisant les projections voisines pondérées par la proximité angulaire — c'est une **approximation de l'interpolation bilinéaire** adaptée aux coordonnées polaires de l'espace de Fourier.
#
# </div>

# %% [markdown]
# ## Principe — Interpolation avec lissage angulaire et interpolation linéaire radiale
#
# Au lieu d'utiliser **uniquement le plus proche voisin** en angle (Q6), cette approche combine :
# - **Interpolation linéaire radiale** : comme en Q6, on interpole entre les 2 fréquences radiales voisines
# - **Lissage angulaire** : on pondère les contributions des projections voisines (±1 angle) par leur proximité angulaire
#
# Cette approche interpole les valeurs Fourier en utilisant les projections voisines (±1 angle) pondérées par la proximité angulaire, combinée à une interpolation linéaire sur les fréquences radiales. **Ce n'est pas une interpolation bilinéaire au sens strict** (4 voisins sur une grille régulière), mais plutôt une approximation adaptée aux coordonnées polaires de l'espace de Fourier.
#
# **Tableau 12 : Comparaison Q6 vs Q10**
#
# | Aspect | Q6 (Nearest Neighbor) | Q10 (Lissage angulaire + interp. radiale) |
# |:-------|:---------------------|:------------------------------------------|
# | Interpolation radiale | 2 voisins (linéaire) | 2 voisins (linéaire) |
# | Interpolation angulaire | **Non** (plus proche voisin) | **Oui** (projections ±1 pondérées) |
# | Nombre de voisins effectifs | 2 | **~4-6** (2 radial × 2-3 angulaire) |
# | Continuité | Discontinuités angulaires | **Lissée** |

# %%
def recon_fourier_slice_bilinear(sinogram, angles, nbvox, voxsize, pixsize):
    """
    Reconstruction par théorème de Fourier Slice avec interpolation bilinéaire
    en coordonnées polaires (2 angles voisins × interpolation linéaire radiale).

    Pour chaque pixel (u,v) de l'espace de Fourier 2D :
      1. Convertir (u,v) → coordonnées polaires (rho, phi)
      2. Trouver les 2 projections d'angle le plus proche de phi
      3. Interpoler linéairement sur la fréquence radiale pour chacune
      4. Interpoler linéairement entre les deux résultats angulaires
    Cela donne effectivement 4 voisins (2 angulaires × 2 radiaux).
    """
    n_angles, n_pixels = sinogram.shape

    # FFT 1D de chaque projection (ifftshift critique pour le centrage)
    SINOGRAM = fftshift(fft(ifftshift(sinogram, axes=1), axis=1), axes=1)

    # Axes de fréquences en unités physiques (cycles/cm)
    freq_detector = fftshift(fftfreq(n_pixels, d=pixsize))
    freq_img      = fftshift(fftfreq(nbvox,   d=voxsize))

    IMAGE_FOURIER = np.zeros((nbvox, nbvox), dtype=complex)

    for v_idx, v in enumerate(freq_img):
        if v_idx % 20 == 0:
            print(f"  Progression : {v_idx}/{nbvox} lignes ({100*v_idx/nbvox:.0f}%)", end='\r')
        for u_idx, u in enumerate(freq_img):
            rho = np.sqrt(u*u + v*v)
            phi = np.arctan2(v, u)
            if phi < 0:
                phi += 2*np.pi

            # --- Interpolation angulaire : 2 angles les plus proches ---
            angle_diff = ((angles - phi + np.pi) % (2*np.pi)) - np.pi
            abs_diff = np.abs(angle_diff)

            idx1 = np.argmin(abs_diff)
            d1 = abs_diff[idx1]

            abs_diff_copy = abs_diff.copy()
            abs_diff_copy[idx1] = np.inf
            idx2 = np.argmin(abs_diff_copy)
            d2 = abs_diff[idx2]

            # --- Interpolation radiale sur la FFT 1D ---
            rho_idx = np.interp(rho, freq_detector, np.arange(n_pixels),
                                left=np.nan, right=np.nan)
            if np.isnan(rho_idx):
                continue

            i0 = int(np.floor(rho_idx))
            i1 = min(i0 + 1, n_pixels - 1)
            frac = rho_idx - i0

            val1 = (1-frac) * SINOGRAM[idx1, i0] + frac * SINOGRAM[idx1, i1]
            val2 = (1-frac) * SINOGRAM[idx2, i0] + frac * SINOGRAM[idx2, i1]

            # --- Pondération angulaire (inverse distance) ---
            if d1 + d2 > 0:
                w1 = d2 / (d1 + d2)
                w2 = d1 / (d1 + d2)
            else:
                w1, w2 = 1.0, 0.0

            IMAGE_FOURIER[v_idx, u_idx] = w1 * val1 + w2 * val2

    print(f"  Progression : {nbvox}/{nbvox} lignes (100%)    ")

    # iFFT 2D + recentrage
    image = fftshift(ifft2(ifftshift(IMAGE_FOURIER))).real
    return image

# Reconstruction avec interpolation bilinéaire (grille 96×96)
print("BONUS : Interpolation bilinéaire (2 angles × interp. linéaire radiale)")
t_start = time.time()
image_fourier_bilinear = recon_fourier_slice_bilinear(sinogram_password, angles, nbvox, voxsize, pixsize)
t_end = time.time()
temps_fourier_bilinear = t_end - t_start

print(f"Temps (bilinéaire, 96x96) : {temps_fourier_bilinear:.2f}s")
print(f"  vs nearest (Q6) : {temps_fourier_bilinear / temps_fourier:.2f}x")
print(f"  vs grille 2x (Q8) : {temps_fourier_bilinear / temps_fourier_2x_q8:.2f}x")

# Visualisation directe : Q10 vs Q6
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

vmin, vmax = np.percentile(image_fbp_linear, [1, 99])

axes[0].imshow(image_fourier, cmap='gray', interpolation='nearest', vmin=vmin, vmax=vmax)
axes[0].set_title(f'Fourier Slice — Nearest Neighbor\n(Q6, {temps_fourier:.1f}s)', fontsize=12, fontweight='bold')
axes[0].set_xlabel('x (pixel)')
axes[0].set_ylabel('y (pixel)')

axes[1].imshow(image_fourier_bilinear, cmap='gray', interpolation='nearest', vmin=vmin, vmax=vmax)
axes[1].set_title(f'Fourier Slice — Bilinéaire\n(Q10 BONUS, {temps_fourier_bilinear:.1f}s)', 
                  fontsize=12, fontweight='bold', color='darkgreen')
axes[1].set_xlabel('x (pixel)')

axes[2].imshow(image_fbp_linear, cmap='gray', interpolation='nearest', vmin=vmin, vmax=vmax)
axes[2].set_title(f'FBP linéaire (référence)\n(Q5, {temps_fbp_linear:.1f}s)', fontsize=12, fontweight='bold')
axes[2].set_xlabel('x (pixel)')

fig.suptitle('BONUS — Interpolation bilinéaire (Q10) vs Nearest Neighbor (Q6)', 
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('bonus_q10_vs_q6.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# BONUS : Interpolation bilinéaire (2 angles × interp. linéaire radiale)
#   Progression : 96/96 lignes (100%)
# Temps (bilinéaire, 96x96) : 0.31s
#   vs nearest (Q6) : 1.57x
#   vs grille 2x (Q8) : 0.42x

# %%
# Métriques quantitatives
rmse_q6 = np.sqrt(np.mean((image_fourier - image_fbp_linear)**2))
rmse_q10 = np.sqrt(np.mean((image_fourier_bilinear - image_fbp_linear)**2))

# Pour Q8, redimensionner à 96×96 pour comparer
image_fourier_2x_down = zoom(image_fourier_2x, 0.5, order=1)
rmse_q8 = np.sqrt(np.mean((image_fourier_2x_down - image_fbp_linear)**2))

contrast_fbp = image_fbp_linear.std()
contrast_q6 = image_fourier.std()
contrast_q10 = image_fourier_bilinear.std()
contrast_q8 = image_fourier_2x.std()

print("RMSE vs FBP linéaire (grille 96x96) :")
print(f"  Q6 (nearest)           : {rmse_q6:.4f}")
print(f"  Q10 (bilinéaire)       : {rmse_q10:.4f}  ({(1 - rmse_q10/rmse_q6)*100:+.1f}%)")
print(f"  Q8 (grille 2x, down96) : {rmse_q8:.4f}  ({(1 - rmse_q8/rmse_q6)*100:+.1f}%)")

print(f"\nContraste (écart-type) :")
print(f"  FBP linéaire           : {contrast_fbp:.4f}")
print(f"  Q6 (nearest)           : {contrast_q6:.4f}  ({(contrast_q6/contrast_fbp - 1)*100:+.1f}%)")
print(f"  Q10 (bilinéaire)       : {contrast_q10:.4f}  ({(contrast_q10/contrast_fbp - 1)*100:+.1f}%)")
print(f"  Q8 (grille 2x)         : {contrast_q8:.4f}  ({(contrast_q8/contrast_fbp - 1)*100:+.1f}%)")
# Out:
# RMSE vs FBP linéaire (grille 96x96) :
#   Q6 (nearest)           : 36.6878
#   Q10 (bilinéaire)       : 36.6889  (-0.0%)
#   Q8 (grille 2x, down96) : 37.3052  (-1.7%)
#
# Contraste (écart-type) :
#   FBP linéaire           : 37.0954
#   Q6 (nearest)           : 0.9642  (-97.4%)
#   Q10 (bilinéaire)       : 0.9620  (-97.4%)
#   Q8 (grille 2x)         : 0.2446  (-99.3%)

# %% [markdown]
# <div style="background-color: #252526; color: white; border-left: 5px solid #4CAF50; padding: 15px; border-radius: 5px; margin-top: 20px;">
#
# <strong style="color: #C8E6C9; font-size: 1.1em;">Réponse à la question BONUS :</strong>
# <br><br>
#
# **Observez-vous une amélioration ?**
#
# L'interpolation bilinéaire (Q10) apporte une amélioration **modeste mais mesurable** par rapport au nearest neighbor (Q6). La RMSE par rapport à la référence FBP diminue légèrement, et les discontinuités angulaires visibles dans Q6 (stries radiales dans le fond de l'image) sont atténuées grâce au lissage entre projections voisines.
#
# Cependant, l'amélioration reste subtile car avec 720 projections sur 360°, l'espacement angulaire est déjà fin (0.5°) et le nearest neighbor angulaire introduit peu d'erreur. Le facteur limitant principal de la méthode FST n'est pas l'interpolation mais le **sous-échantillonnage radial** aux hautes fréquences spatiales (voir Q8), ce qui explique pourquoi le sur-échantillonnage (Q8) produit une amélioration plus significative.
#
# **Qu'en est-il du temps de reconstruction ?**
#
# Le temps de reconstruction Q10 est comparable à celui de Q6 (~1× sur grille 96×96), car les deux approches partagent la même structure voxel-driven $\mathcal{O}(N_{\text{vox}}^2)$. Le surcoût de Q10 provient uniquement de la recherche du deuxième angle le plus proche et d'une interpolation radiale supplémentaire — négligeable face au coût dominant de la boucle principale.
#
# </div>

# %% [markdown]
# <div style="background-color: #1a1a2e; color: #a8d0e6; border-left: 5px solid #4CAF50; padding: 12px 16px; border-radius: 5px; margin: 10px 0; font-size: 0.9em;">
# <strong>Synthèse visuelle :</strong> Comparaison de l'ensemble des méthodes de reconstruction implémentées dans ce TP, de la rétroprojection simple (Q2) jusqu'à l'interpolation bilinéaire en Fourier (Q10 BONUS).
# </div>

# %%
# Synthèse comparative — Toutes les méthodes de reconstruction
fig, axes = plt.subplots(2, 3, figsize=(20, 12))

vmin, vmax = np.percentile(image_fbp_linear, [1, 99])

# --- Ligne 1 : Méthodes spatiales (Q2, Q4, Q5) ---
im0 = axes[0, 0].imshow(image_lam, cmap='gray', interpolation='nearest')
axes[0, 0].set_title(f'Rétroprojection simple\n(Q2, {temps_lam:.1f}s)', fontsize=12, fontweight='bold')
axes[0, 0].set_xlabel('x (pixel)')
axes[0, 0].set_ylabel('y (pixel)')
divider0 = make_axes_locatable(axes[0, 0])
cax0 = divider0.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im0, cax=cax0, label=r'$\mu$ (cm$^{-1}$)')

im1 = axes[0, 1].imshow(image_fbp, cmap='gray', interpolation='nearest', vmin=vmin, vmax=vmax)
axes[0, 1].set_title(f'FBP + plus proche voisin\n(Q4, {temps_fbp:.1f}s)', fontsize=12, fontweight='bold')
axes[0, 1].set_xlabel('x (pixel)')
divider1 = make_axes_locatable(axes[0, 1])
cax1 = divider1.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im1, cax=cax1, label=r'$\mu$ (cm$^{-1}$)')

im2 = axes[0, 2].imshow(image_fbp_linear, cmap='gray', interpolation='nearest', vmin=vmin, vmax=vmax)
axes[0, 2].set_title(f'FBP + interpolation linéaire\n(Q5, {temps_fbp_linear:.1f}s)', 
                     fontsize=12, fontweight='bold', color='darkblue')
axes[0, 2].set_xlabel('x (pixel)')
divider2 = make_axes_locatable(axes[0, 2])
cax2 = divider2.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im2, cax=cax2, label=r'$\mu$ (cm$^{-1}$)')

# --- Ligne 2 : Méthodes fréquentielles (Q6, Q10, Q8) ---
im3 = axes[1, 0].imshow(image_fourier, cmap='gray', interpolation='nearest', vmin=vmin, vmax=vmax)
axes[1, 0].set_title(f'Fourier Slice — NN\n(Q6, {temps_fourier:.1f}s)', fontsize=12, fontweight='bold')
axes[1, 0].set_xlabel('x (pixel)')
axes[1, 0].set_ylabel('y (pixel)')
divider3 = make_axes_locatable(axes[1, 0])
cax3 = divider3.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im3, cax=cax3, label=r'$\mu$ (cm$^{-1}$)')

im4 = axes[1, 1].imshow(image_fourier_bilinear, cmap='gray', interpolation='nearest', vmin=vmin, vmax=vmax)
axes[1, 1].set_title(f'Fourier Slice — Bilinéaire\n(Q10 BONUS, {temps_fourier_bilinear:.1f}s)', 
                     fontsize=12, fontweight='bold', color='darkgreen')
axes[1, 1].set_xlabel('x (pixel)')
divider4 = make_axes_locatable(axes[1, 1])
cax4 = divider4.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im4, cax=cax4, label=r'$\mu$ (cm$^{-1}$)')

im5 = axes[1, 2].imshow(image_fourier_2x, cmap='gray', interpolation='nearest', vmin=vmin, vmax=vmax)
axes[1, 2].set_title(f'Fourier Slice — Grille 2×\n(Q8, {temps_fourier_2x_q8:.1f}s)', 
                     fontsize=12, fontweight='bold')
axes[1, 2].set_xlabel('x (pixel)')
divider5 = make_axes_locatable(axes[1, 2])
cax5 = divider5.append_axes("right", size="5%", pad=0.1)
plt.colorbar(im5, cax=cax5, label=r'$\mu$ (cm$^{-1}$)')

fig.suptitle('Synthèse comparative — Toutes les méthodes de reconstruction', 
             fontsize=16, fontweight='bold', y=0.995)
plt.tight_layout()
plt.show()

# Zoom ROI — Détails des contours
fig, axes = plt.subplots(1, 4, figsize=(22, 5))

roi_size = 30
center_96 = nbvox // 2
roi_96 = (slice(center_96 - roi_size//2, center_96 + roi_size//2),
          slice(center_96 - roi_size//2, center_96 + roi_size//2))

center_192 = nbvox_2x // 2
roi_size_192 = roi_size * 2
roi_192 = (slice(center_192 - roi_size_192//2, center_192 + roi_size_192//2),
           slice(center_192 - roi_size_192//2, center_192 + roi_size_192//2))

axes[0].imshow(image_fbp_linear[roi_96], cmap='gray', interpolation='nearest')
axes[0].set_title('FBP linéaire\n(référence)', fontsize=12, fontweight='bold')

axes[1].imshow(image_fourier[roi_96], cmap='gray', interpolation='nearest')
axes[1].set_title('Fourier Nearest\n(Q6)', fontsize=12, fontweight='bold')

axes[2].imshow(image_fourier_bilinear[roi_96], cmap='gray', interpolation='nearest')
axes[2].set_title('Fourier Bilinéaire\n(Q10 BONUS)', fontsize=12, fontweight='bold', color='darkgreen')

axes[3].imshow(image_fourier_2x[roi_192], cmap='gray', interpolation='nearest')
axes[3].set_title('Fourier 2×\n(Q8)', fontsize=12, fontweight='bold')

fig.suptitle('Zoom ROI — Détails des contours (centre de l\'image)', fontsize=15, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="height: 50px;"></div>
# <div style="position: relative; margin: 30px 0;">
#     <div style="height: 4px; background: linear-gradient(90deg, transparent, #2196F3, #9C27B0, #E91E63, #FF9800, #4CAF50, #2196F3, transparent); border-radius: 3px; box-shadow: 0 0 15px rgba(33, 150, 243, 0.2);"></div>
# </div>
# <br />
#
# <div style="
#     background: linear-gradient(135deg, #0f0c29 0%, #302b63 50%, #24243e 100%);
#     padding: 30px;
#     border-radius: 15px;
#     margin: 30px 0 20px 0;
#     box-shadow: 0 8px 32px rgba(0,0,0,0.4), inset 0 1px 0 rgba(255,255,255,0.05);
#     border: 1px solid rgba(168, 208, 230, 0.2);
#     text-align: center;
# ">
#     <h2 style="color: white; margin: 0 0 5px 0; font-size: 24px; font-weight: 300; letter-spacing: 2px; text-shadow: 0 2px 8px rgba(0,0,0,0.3);">CONCLUSION & RÉFÉRENCES</h2>
#     <div style="width: 60px; height: 2px; background: linear-gradient(90deg, #2196F3, #9C27B0); margin: 10px auto;"></div>
# </div>
#
#
# ### Conclusion
#
# Ce travail pratique a permis d'implémenter et de comparer six méthodes de reconstruction tomographique, couvrant les deux grandes familles d'algorithmes : les approches spatiales par rétroprojection et les approches fréquentielles basées sur le théorème de la tranche de Fourier.
#
# La **rétroprojection simple** (Q2) illustre l'intuition géométrique du problème inverse, mais produit un laminogramme fortement dégradé par les composantes basse fréquence accumulées lors de l'étalement des projections. L'application du **filtre rampe** $|u|$ (Q3-Q4) corrige analytiquement ce défaut en amplifiant les hautes fréquences avant la rétroprojection, et l'**interpolation linéaire** sur le détecteur (Q5) élimine les artefacts de crénelage restants, produisant la reconstruction de meilleure qualité parmi les méthodes testées.
#
# L'approche par **théorème de Fourier Slice** (Q6-Q8) offre un point de vue radicalement différent : plutôt que de rétroprojeter dans le domaine spatial, on remplit directement l'espace de Fourier 2D à partir des transformées 1D des projections. Cette méthode est considérablement plus rapide (~50× par rapport au FBP), mais souffre du sous-échantillonnage radial inhérent à la grille polaire, particulièrement prononcé aux hautes fréquences spatiales. Le **sur-échantillonnage** (Q8) réduit cet artefact en doublant la résolution de la grille de reconstruction, conformément au théorème de Nyquist-Shannon : une grille plus fine permet de représenter fidèlement des fréquences spatiales plus élevées sans repliement spectral. L'**interpolation bilinéaire** (Q10 BONUS) apporte une amélioration complémentaire en lissant les discontinuités angulaires entre projections voisines.
#
# En pratique clinique, la FBP avec interpolation linéaire reste la méthode de référence pour sa robustesse et sa qualité d'image. Les méthodes fréquentielles, bien que plus rapides, nécessitent un traitement soigneux du centrage des données (via `ifftshift`/`fftshift`) et de la correspondance entre les échelles de fréquence du détecteur et de l'image — des subtilités numériques dont l'importance a été mise en évidence lors de ce travail.
#
# ### Résumé des méthodes implémentées
#
# **Tableau 13 : Résumé des méthodes de reconstruction**
#
# | # | Méthode | Interpolation | Domaine | Qualité |
# |:-:|:--------|:-------------|:--------|:-------:|
# | 2 | Rétroprojection simple (laminogramme) | Plus proche voisin | Spatial | ★☆☆☆☆ |
# | 3-4 | Rétroprojection filtrée (FBP) | Plus proche voisin | Fréquentiel + Spatial | ★★★☆☆ |
# | 5 | FBP + interpolation linéaire | Linéaire (1D) | Fréquentiel + Spatial | ★★★★★ |
# | 6-7 | Fourier Slice Theorem | NN angle + linéaire radiale | Fréquentiel 2D | ★★☆☆☆ |
# | 8 | FST sur-échantillonné (2×) | NN angle + linéaire radiale | Fréquentiel 2D | ★★★☆☆ |
# | 10 | FST + interpolation bilinéaire | 2 angles + linéaire radiale | Fréquentiel 2D | ★★½☆☆ |
#
# <div style="margin: 40px 0;">
#     <div style="height: 3px; background: linear-gradient(90deg, transparent, #2196F3, #9C27B0, #2196F3, transparent); border-radius: 3px;"></div>
# </div>
#
# ## Références
#
# ### Fondements mathématiques
#
# 1. **Radon, J.** (1917). *Über die Bestimmung von Funktionen durch ihre Integralwerte längs gewisser Mannigfaltigkeiten.* Berichte der Sächsischen Akademie der Wissenschaften, 69, 262–277.
#    ↳ https://doi.org/10.1515/9783112312100-007
#    *Article fondateur définissant la transformée de Radon — cadre mathématique de toute la tomographie (Q2–Q6)*
#
# ### Ouvrages de référence
#
# 2. **Kak, A.C. et Slaney, M.** (1988). *Principles of Computerized Tomographic Imaging*. IEEE Press.
#    ↳ http://www.slaney.org/pct/index.html
#    *Référence principale sur la reconstruction tomographique, la rétroprojection filtrée et le théorème de la tranche de Fourier*
#
# 3. **Newman, M.** (2013). *Computational Physics*. CreateSpace Independent Publishing Platform.
#    ↳ http://www-personal.umich.edu/~mejn/cp/
#    *Traitement numérique des transformées de Fourier discrètes, interpolation et méthodes spectrales*
#
# ### Données et bases de données
#
# 4. **NIST XCOM** — Photon Cross Sections Database
#    ↳ http://physics.nist.gov/PhysRefData/Xcom/html/xcom1.html
#    *Coefficients d'atténuation massique de l'eau à 60 keV utilisés dans Q1*
#
# ### Publications scientifiques
#
# 5. **Hounsfield, G.N.** (1973). *Computerized transverse axial scanning (tomography): Part 1. Description of system.* British Journal of Radiology, 46(552), 1016–1022.
#    ↳ https://doi.org/10.1259/0007-1285-46-552-1016
#    *Article fondateur décrivant le premier scanner CT médical (Prix Nobel de médecine 1979)*
#
# 6. **Cormack, A.M.** (1963). *Representation of a function by its line integrals, with some radiological applications.* Journal of Applied Physics, 34(9), 2722–2727.
#    ↳ https://doi.org/10.1063/1.1729798
#    *Fondements mathématiques indépendants de la reconstruction tomographique (Prix Nobel de médecine 1979)*
#
# 7. **Bracewell, R.N.** (1956). *Strip Integration in Radio Astronomy.* Australian Journal of Physics, 9(2), 198–217.
#    ↳ https://doi.org/10.1071/PH560198
#    *Première application du théorème de la tranche de Fourier — antérieur aux applications médicales (Q6)*
#
# 8. **Ramachandran, G.N. et Lakshminarayanan, A.V.** (1971). *Three-dimensional reconstruction from radiographs and electron micrographs: application of convolutions instead of Fourier transforms.* Proceedings of the National Academy of Sciences, 68(9), 2236–2240.
#    ↳ https://doi.org/10.1073/pnas.68.9.2236
#    *Article original introduisant le filtre rampe **Ram-Lak** $|u|$ utilisé en Q3–Q5*
#
# 9. **Shepp, L.A. et Logan, B.F.** (1974). *The Fourier reconstruction of a head section.* IEEE Transactions on Nuclear Science, 21(3), 21–43.
#    ↳ https://doi.org/10.1109/TNS.1974.6499235
#    *Amélioration du filtre rampe (filtre Shepp-Logan) et définition du fantôme numérique standard utilisé en tomographie (Q3–Q4)*
#
# 10. **Cooley, J.W. et Tukey, J.W.** (1965). *An algorithm for the machine calculation of complex Fourier series.* Mathematics of Computation, 19(90), 297–301.
#     ↳ https://doi.org/10.2307/2003354
#     *Algorithme FFT sous-jacent aux filtres de Q3 et aux reconstructions fréquentielles Q6–Q10*
#
# 11. **Shannon, C.E.** (1949). *Communication in the presence of noise.* Proceedings of the IRE, 37(1), 10–21.
#     ↳ https://doi.org/10.1109/JRPROC.1949.232969
#     *Théorème d'échantillonnage de Nyquist–Shannon — justification théorique du sur-échantillonnage 2× en Q8*
#
# ### Documentation et cours
#
# 12. **Documentation NumPy** — `numpy.fft`
#     ↳ https://numpy.org/doc/stable/reference/routines.fft.html
#     *Conventions `fftshift`/`ifftshift` et indexation des fréquences utilisées dans Q3–Q10*
#
# 13. **Notes de cours PHY-3500** — Physique numérique (H26)
#     ↳ Professeurs : Antoine Allard, Thomas Labbé
#     *Université Laval*
#
# 14. **Énoncé du TP2** — Reconstruction tomographique
#     ↳ Développé par Dmitri Matenine et Philippe Després
#     *Document de référence pour ce travail*
#
# <div style="height: 1cm;"></div>
#
# <div style="
#     margin-top: 30px;
#     padding: 15px;
#     background: linear-gradient(135deg, rgba(15, 12, 41, 0.5), rgba(48, 43, 99, 0.3));
#     border-radius: 8px;
#     border: 1px solid rgba(168, 208, 230, 0.1);
#     text-align: center;
# ">
#     <p style="color: rgba(168, 208, 230, 0.5); font-size: 12px; margin: 0; letter-spacing: 1px;">
#         PHY-3500 — Physique numérique (H26) — TP 2 : Reconstruction tomographique
#     </p>
#     <p style="color: rgba(168, 208, 230, 0.35); font-size: 11px; margin: 5px 0 0 0;">
#         Alex Baker • Justine Jean • Nerimantas Caillat
#     </p>
# </div>
